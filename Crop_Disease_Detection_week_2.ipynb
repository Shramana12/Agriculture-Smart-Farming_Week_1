# %%
#Imports

import os
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import tensorflow as tf
from collections import Counter

# %%
# INPUT
data_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_color")

# %%
total_images = 0

for class_name in os.listdir(data_dir):
    class_path = data_dir / class_name
    
    if class_path.is_dir():
        num_images = len(os.listdir(class_path))
        total_images += num_images

print("Total Images:", total_images)
# Out:
# Total Images: 54305

# %%
#Exploratory Data Analysis(EDA)
#Class Distribution

class_counts = {}

for class_name in os.listdir(data_dir):
    class_path = data_dir / class_name
    if class_path.is_dir():
        class_counts[class_name] = len(os.listdir(class_path))

# Print counts
for k, v in class_counts.items():
    print(f"{k}: {v}")
# Out:
# Apple___Apple_scab: 630
# Apple___Black_rot: 621
# Apple___Cedar_apple_rust: 275
# Apple___healthy: 1645
# Blueberry___healthy: 1502
# Cherry_(including_sour)___healthy: 854
# Cherry_(including_sour)___Powdery_mildew: 1052
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 513
# Corn_(maize)___Common_rust_: 1192
# Corn_(maize)___healthy: 1162
# Corn_(maize)___Northern_Leaf_Blight: 985
# Grape___Black_rot: 1180
# Grape___Esca_(Black_Measles): 1383
# Grape___healthy: 423
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 1076
# Orange___Haunglongbing_(Citrus_greening): 5507
# Peach___Bacterial_spot: 2297
# Peach___healthy: 360
# Pepper,_bell___Bacterial_spot: 997
# Pepper,_bell___healthy: 1478
# Potato___Early_blight: 1000
# Potato___healthy: 152
# Potato___Late_blight: 1000
# Raspberry___healthy: 371
# Soybean___healthy: 5090
# Squash___Powdery_mildew: 1835
# Strawberry___healthy: 456
# Strawberry___Leaf_scorch: 1109
# Tomato___Bacterial_spot: 2127
# Tomato___Early_blight: 1000
# Tomato___healthy: 1591
# Tomato___Late_blight: 1909
# Tomato___Leaf_Mold: 952
# Tomato___Septoria_leaf_spot: 1771
# Tomato___Spider_mites Two-spotted_spider_mite: 1676
# Tomato___Target_Spot: 1404
# Tomato___Tomato_mosaic_virus: 373
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 5357

# %%
#Plot Class Distribution

plt.figure(figsize=(12,5))
plt.bar(class_counts.keys(), class_counts.values())
plt.xticks(rotation=90)
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %%
#Sample Image Visualization


plt.figure(figsize=(12,8))

classes = list(class_counts.keys())

for i, class_name in enumerate(classes[:9]):  # first 9 classes
    class_path = data_dir / class_name
    img_name = random.choice(os.listdir(class_path))
    img_path = class_path / img_name
    
    img = plt.imread(img_path)
    
    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#Train/Val/Test Split
#Split Function

import shutil
# OUTPUT
output_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")

train_dir = output_dir / "train"
val_dir   = output_dir / "val"
test_dir  = output_dir / "test"


for folder in [train_dir, val_dir, test_dir]:
    folder.mkdir(parents=True, exist_ok=True)

train_ratio = 0.7
val_ratio   = 0.15
test_ratio  = 0.15

# %%
import os, shutil, random
from pathlib import Path

# ✅ INPUT DATASET
data_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_color")

# ✅ OUTPUT
output_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")

train_dir = output_dir / "train"
test_dir  = output_dir / "test"
val_dir = output_dir / "val"

# ✅ clean old split (IMPORTANT)
if output_dir.exists():
    shutil.rmtree(output_dir)

train_dir.mkdir(parents=True, exist_ok=True)
test_dir.mkdir(parents=True, exist_ok=True)
val_dir.mkdir(parents=True, exist_ok=True)
for class_name in os.listdir(data_dir):
    class_path = data_dir / class_name

    if not class_path.is_dir():
        continue

    images = [
        img for img in os.listdir(class_path)
        if img.lower().endswith(('.jpg', '.jpeg', '.png'))
    ]

    random.shuffle(images)

    # ✅ CORRECT INDENTATION
    train_split = int(0.7 * len(images))
    val_split   = int(0.85 * len(images))

    train_images = images[:train_split]
    val_images   = images[train_split:val_split]
    test_images  = images[val_split:]

    for split_name, split_images in zip(
        ['train', 'val', 'test'],
        [train_images, val_images, test_images]
    ):
        split_dir = output_dir / split_name

        (split_dir / class_name).mkdir(parents=True, exist_ok=True)

        for img in split_images:
            src = class_path / img
            dst = split_dir / class_name / img

            shutil.copy2(src, dst)
print("✅ Data Split Done")
# Out:
# ✅ Data Split Done

# %%
data_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_color")

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224,224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224,224),
    batch_size=32
)
# Out:
# Found 54305 files belonging to 38 classes.
# Using 43444 files for training.
# Found 54305 files belonging to 38 classes.
# Using 10861 files for validation.

# %%
#Normalize + Prefetch

normalization_layer = tf.keras.layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y))


AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)

# %%
def print_dataset_details(folder, name):
    print(f"\n📂 {name} Folder:")
    
    total = 0
    
    for class_name in os.listdir(folder):
        class_path = folder / class_name
        
        if class_path.is_dir():
            num_images = len(os.listdir(class_path))
            total += num_images
            print(f"{class_name}: {num_images}")
    
    print(f"👉 Total {name} Images: {total}")
print_dataset_details(train_dir, "Train")
print_dataset_details(val_dir, "Validation")
print_dataset_details(test_dir, "Test")
# Out:
# 📂 Train Folder:
# Apple___Apple_scab: 441
# Apple___Black_rot: 434
# Apple___Cedar_apple_rust: 192
# Apple___healthy: 1151
# Blueberry___healthy: 1051
# Cherry_(including_sour)___healthy: 597
# Cherry_(including_sour)___Powdery_mildew: 736
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 359
# Corn_(maize)___Common_rust_: 834
# Corn_(maize)___healthy: 813
# Corn_(maize)___Northern_Leaf_Blight: 689
# Grape___Black_rot: 826
# Grape___Esca_(Black_Measles): 968
# Grape___healthy: 296
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 753
# Orange___Haunglongbing_(Citrus_greening): 3854
# Peach___Bacterial_spot: 1607
# Peach___healthy: 251
# Pepper,_bell___Bacterial_spot: 697
# Pepper,_bell___healthy: 1034
# Potato___Early_blight: 700
# Potato___healthy: 106
# Potato___Late_blight: 700
# Raspberry___healthy: 259
# Soybean___healthy: 3563
# Squash___Powdery_mildew: 1284
# Strawberry___healthy: 319
# Strawberry___Leaf_scorch: 776
# Tomato___Bacterial_spot: 1488
# Tomato___Early_blight: 700
# Tomato___healthy: 1113
# Tomato___Late_blight: 1336
# Tomato___Leaf_Mold: 666
# Tomato___Septoria_leaf_spot: 1239
# Tomato___Spider_mites Two-spotted_spider_mite: 1173
# Tomato___Target_Spot: 982
# Tomato___Tomato_mosaic_virus: 261
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 3749
# 👉 Total Train Images: 37997
#
# 📂 Validation Folder:
# Apple___Apple_scab: 94
# Apple___Black_rot: 93
# Apple___Cedar_apple_rust: 41
# Apple___healthy: 247
# Blueberry___healthy: 225
# Cherry_(including_sour)___healthy: 128
# Cherry_(including_sour)___Powdery_mildew: 158
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 77
# Corn_(maize)___Common_rust_: 179
# Corn_(maize)___healthy: 174
# Corn_(maize)___Northern_Leaf_Blight: 148
# Grape___Black_rot: 177
# Grape___Esca_(Black_Measles): 207
# Grape___healthy: 63
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 161
# Orange___Haunglongbing_(Citrus_greening): 826
# Peach___Bacterial_spot: 345
# Peach___healthy: 55
# Pepper,_bell___Bacterial_spot: 150
# Pepper,_bell___healthy: 222
# Potato___Early_blight: 150
# Potato___healthy: 23
# Potato___Late_blight: 150
# Raspberry___healthy: 56
# Soybean___healthy: 763
# Squash___Powdery_mildew: 275
# Strawberry___healthy: 68
# Strawberry___Leaf_scorch: 166
# Tomato___Bacterial_spot: 319
# Tomato___Early_blight: 150
# Tomato___healthy: 239
# Tomato___Late_blight: 286
# Tomato___Leaf_Mold: 143
# Tomato___Septoria_leaf_spot: 266
# Tomato___Spider_mites Two-spotted_spider_mite: 251
# Tomato___Target_Spot: 211
# Tomato___Tomato_mosaic_virus: 56
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 804
# 👉 Total Validation Images: 8146
#
# 📂 Test Folder:
# Apple___Apple_scab: 95
# Apple___Black_rot: 94
# Apple___Cedar_apple_rust: 42
# Apple___healthy: 247
# Blueberry___healthy: 226
# Cherry_(including_sour)___healthy: 129
# Cherry_(including_sour)___Powdery_mildew: 158
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 77
# Corn_(maize)___Common_rust_: 179
# Corn_(maize)___healthy: 175
# Corn_(maize)___Northern_Leaf_Blight: 148
# Grape___Black_rot: 177
# Grape___Esca_(Black_Measles): 208
# Grape___healthy: 64
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 162
# Orange___Haunglongbing_(Citrus_greening): 827
# Peach___Bacterial_spot: 345
# Peach___healthy: 54
# Pepper,_bell___Bacterial_spot: 150
# Pepper,_bell___healthy: 222
# Potato___Early_blight: 150
# Potato___healthy: 23
# Potato___Late_blight: 150
# Raspberry___healthy: 56
# Soybean___healthy: 764
# Squash___Powdery_mildew: 276
# Strawberry___healthy: 69
# Strawberry___Leaf_scorch: 167
# Tomato___Bacterial_spot: 320
# Tomato___Early_blight: 150
# Tomato___healthy: 239
# Tomato___Late_blight: 287
# Tomato___Leaf_Mold: 143
# Tomato___Septoria_leaf_spot: 266
# Tomato___Spider_mites Two-spotted_spider_mite: 252
# Tomato___Target_Spot: 211
# Tomato___Tomato_mosaic_virus: 56
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 804
# 👉 Total Test Images: 8162

# %% [markdown]
# ### WEEK 2: Custom CNN Architecture and Baseline Training

# %%
# =====================================================
# IMPORTS
# =====================================================
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt


print("✅ All libraries imported successfully")
# Out:
# ✅ All libraries imported successfully

# %%
# =====================================================
# PATHS
# =====================================================
base_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")
train_dir = base_dir / "train"
val_dir = base_dir / "val"
test_dir = base_dir / "test"

MODEL_PATH = "best_cnn_model.keras"

# =====================================================
# CONFIG
# =====================================================
IMG_SIZE = (128, 128)
BATCH_SIZE = 16
EPOCHS = 500
NUM_CLASSES = len(os.listdir(train_dir)) #Auto-detect number of class

print(f"Train : {train_dir}")
print(f" Val : {val_dir}")
print(f" Test : {test_dir}")
print(f" Number of Classes : {NUM_CLASSES}")
# Out:
# Train : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\train
#  Val : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\val
#  Test : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\test
#  Number of Classes : 38

# %%
# =====================================================
# DATA GENERATOR
# =====================================================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    fill_mode="nearest"
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

NUM_CLASSES = len(train_generator.class_indices)


NUM_CLASSES= len(train_generator.class_indices)
print(f" Classes loaded: {NUM_CLASSES} classes")
print(f" Train batches : {len(train_generator)}")
print(f" val batches : {len(val_generator)}")
print(f" Test batches : {len(test_generator)}")
# Out:
# Found 37997 images belonging to 38 classes.
# Found 8146 images belonging to 38 classes.
# Found 8162 images belonging to 38 classes.
#  Classes loaded: 38 classes
#  Train batches : 2375
#  val batches : 510
#  Test batches : 511

# %%
# Visualize Augmented Images (sanity check)
import matplotlib.pyplot as plt
import numpy as np

class_names = list(train_generator.class_indices.keys())

sample_batch, sample_labels = next(train_generator)

fig, axes = plt.subplots(3, 4, figsize =(14, 10))
fig.suptitle('Sample Augmented Training Images', fontsize= 16, fontweight= 'bold')

for i, ax in enumerate(axes.flatten()):
    ax.imshow(sample_batch[i])
    label_idx = np.argmax(sample_labels[i])
    ax.set_title(class_names[label_idx][:25],fontsize=8)
    ax.axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('augmented_samples.png',dpi =100, bbox_inches='tight')
plt.show()
print("Augmented Sample images displayed")
# Out:
# Augmented Sample images displayed

# %%
# =====================================================
# MODEL
# =====================================================
def build_custom_cnn(num_classes):
    model = models.Sequential([
        layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(128,128,3)),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model
    

num_classes = 38  
model = build_custom_cnn(num_classes)

model.summary()
# Out:
# C:\Users\Prarthana\.conda\envs\tf_env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 38)                  │           9,766 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 136,038 (531.40 KB)
#  Trainable params: 136,038 (531.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# =====================================================
# CALLBACKS
# =====================================================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    MODEL_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

print(f"✅ Calbacks configured")
print("   • EarlyStopping    (patience=5) ")
print("   • ModelCheckpoint  (save best model)")
print("   • ReduceLROnPlateau (patience=3)")
# Out:
# ✅ Calbacks configured
#    • EarlyStopping    (patience=5)
#    • ModelCheckpoint  (save best model)
#    • ReduceLROnPlateau (patience=3)

# %%
print("Train:", len(train_generator.class_indices))
print("Val:", len(val_generator.class_indices))

print("\nTrain classes:")
print(train_generator.class_indices)

print("\nVal classes:")
print(val_generator.class_indices)
# Out:
# Train: 38
# Val: 38
#
# Train classes:
# {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}
#
# Val classes:
# {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}

# %%
# =====================================================
# 🔥 FIRST TRAINING
# =====================================================
print("\n🚀 FIRST TRAINING STARTED")

model = build_custom_cnn(NUM_CLASSES)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history1 = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[early_stop, checkpoint, reduce_lr],
    verbose=1
)

print("✅ First training done")
# Out:
# 🚀 FIRST TRAINING STARTED
# Epoch 1/500
# C:\Users\Prarthana\.conda\envs\tf_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.2304 - loss: 2.8792
# Epoch 1: val_accuracy improved from None to 0.53744, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 399s 167ms/step - accuracy: 0.3220 - loss: 2.4580 - val_accuracy: 0.5374 - val_loss: 1.5527 - learning_rate: 0.0010
# Epoch 2/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5466 - loss: 1.5240
# Epoch 2: val_accuracy improved from 0.53744 to 0.62227, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 85ms/step - accuracy: 0.5835 - loss: 1.3905 - val_accuracy: 0.6223 - val_loss: 1.2533 - learning_rate: 0.0010
# Epoch 3/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6698 - loss: 1.0902
# Epoch 3: val_accuracy improved from 0.62227 to 0.71532, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 210s 88ms/step - accuracy: 0.6882 - loss: 1.0318 - val_accuracy: 0.7153 - val_loss: 0.9237 - learning_rate: 0.0010
# Epoch 4/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7272 - loss: 0.8828
# Epoch 4: val_accuracy improved from 0.71532 to 0.74736, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 85ms/step - accuracy: 0.7388 - loss: 0.8461 - val_accuracy: 0.7474 - val_loss: 0.8282 - learning_rate: 0.0010
# Epoch 5/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7667 - loss: 0.7490
# Epoch 5: val_accuracy improved from 0.74736 to 0.81979, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 199s 84ms/step - accuracy: 0.7761 - loss: 0.7144 - val_accuracy: 0.8198 - val_loss: 0.5636 - learning_rate: 0.0010
# Epoch 6/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7914 - loss: 0.6635
# Epoch 6: val_accuracy did not improve from 0.81979
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 84ms/step - accuracy: 0.8014 - loss: 0.6293 - val_accuracy: 0.8143 - val_loss: 0.5789 - learning_rate: 0.0010
# Epoch 7/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8207 - loss: 0.5822
# Epoch 7: val_accuracy improved from 0.81979 to 0.82458, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.8246 - loss: 0.5626 - val_accuracy: 0.8246 - val_loss: 0.5926 - learning_rate: 0.0010
# Epoch 8/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8364 - loss: 0.5165
# Epoch 8: val_accuracy did not improve from 0.82458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 200s 84ms/step - accuracy: 0.8393 - loss: 0.5036 - val_accuracy: 0.7907 - val_loss: 0.7282 - learning_rate: 0.0010
# Epoch 9/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8499 - loss: 0.4720
# Epoch 9: val_accuracy improved from 0.82458 to 0.86116, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.8525 - loss: 0.4641 - val_accuracy: 0.8612 - val_loss: 0.4536 - learning_rate: 0.0010
# Epoch 10/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8600 - loss: 0.4346
# Epoch 10: val_accuracy did not improve from 0.86116
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.8644 - loss: 0.4218 - val_accuracy: 0.8583 - val_loss: 0.4957 - learning_rate: 0.0010
# Epoch 11/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8758 - loss: 0.3920
# Epoch 11: val_accuracy improved from 0.86116 to 0.89467, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 200s 84ms/step - accuracy: 0.8750 - loss: 0.3949 - val_accuracy: 0.8947 - val_loss: 0.3353 - learning_rate: 0.0010
# Epoch 12/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8794 - loss: 0.3719
# Epoch 12: val_accuracy improved from 0.89467 to 0.90093, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.8815 - loss: 0.3683 - val_accuracy: 0.9009 - val_loss: 0.3221 - learning_rate: 0.0010
# Epoch 13/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8843 - loss: 0.3581
# Epoch 13: val_accuracy did not improve from 0.90093
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.8868 - loss: 0.3550 - val_accuracy: 0.8934 - val_loss: 0.3386 - learning_rate: 0.0010
# Epoch 14/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8917 - loss: 0.3452
# Epoch 14: val_accuracy did not improve from 0.90093
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.8948 - loss: 0.3322 - val_accuracy: 0.8785 - val_loss: 0.3974 - learning_rate: 0.0010
# Epoch 15/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8973 - loss: 0.3172
# Epoch 15: val_accuracy did not improve from 0.90093
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.8983 - loss: 0.3151 - val_accuracy: 0.8997 - val_loss: 0.3530 - learning_rate: 0.0010
# Epoch 16/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9040 - loss: 0.2877
# Epoch 16: val_accuracy improved from 0.90093 to 0.90854, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9043 - loss: 0.2943 - val_accuracy: 0.9085 - val_loss: 0.2935 - learning_rate: 0.0010
# Epoch 17/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9086 - loss: 0.2886
# Epoch 17: val_accuracy improved from 0.90854 to 0.91579, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 207s 87ms/step - accuracy: 0.9107 - loss: 0.2830 - val_accuracy: 0.9158 - val_loss: 0.2825 - learning_rate: 0.0010
# Epoch 18/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9148 - loss: 0.2646
# Epoch 18: val_accuracy improved from 0.91579 to 0.92696, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9139 - loss: 0.2678 - val_accuracy: 0.9270 - val_loss: 0.2363 - learning_rate: 0.0010
# Epoch 19/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9166 - loss: 0.2550
# Epoch 19: val_accuracy did not improve from 0.92696
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.9167 - loss: 0.2568 - val_accuracy: 0.9250 - val_loss: 0.2684 - learning_rate: 0.0010
# Epoch 20/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9143 - loss: 0.2574
# Epoch 20: val_accuracy did not improve from 0.92696
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.9172 - loss: 0.2518 - val_accuracy: 0.9132 - val_loss: 0.2918 - learning_rate: 0.0010
# Epoch 21/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9257 - loss: 0.2340
# Epoch 21: val_accuracy did not improve from 0.92696
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.9234 - loss: 0.2386 - val_accuracy: 0.9024 - val_loss: 0.3830 - learning_rate: 0.0010
# Epoch 22/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9270 - loss: 0.2252
# Epoch 22: val_accuracy did not improve from 0.92696
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.9255 - loss: 0.2305 - val_accuracy: 0.9222 - val_loss: 0.2567 - learning_rate: 0.0010
# Epoch 23/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9257 - loss: 0.2266
# Epoch 23: val_accuracy did not improve from 0.92696
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.9261 - loss: 0.2295 - val_accuracy: 0.9014 - val_loss: 0.3547 - learning_rate: 0.0010
# Epoch 24/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9455 - loss: 0.1675
# Epoch 24: val_accuracy did not improve from 0.92696
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9479 - loss: 0.1625 - val_accuracy: 0.9256 - val_loss: 0.2790 - learning_rate: 5.0000e-04
# Epoch 25/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9502 - loss: 0.1494
# Epoch 25: val_accuracy improved from 0.92696 to 0.94709, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9503 - loss: 0.1522 - val_accuracy: 0.9471 - val_loss: 0.1755 - learning_rate: 5.0000e-04
# Epoch 26/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9506 - loss: 0.1531
# Epoch 26: val_accuracy improved from 0.94709 to 0.95458, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9515 - loss: 0.1486 - val_accuracy: 0.9546 - val_loss: 0.1702 - learning_rate: 5.0000e-04
# Epoch 27/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9498 - loss: 0.1527
# Epoch 27: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9512 - loss: 0.1459 - val_accuracy: 0.9356 - val_loss: 0.2427 - learning_rate: 5.0000e-04
# Epoch 28/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9531 - loss: 0.1386
# Epoch 28: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9520 - loss: 0.1435 - val_accuracy: 0.9380 - val_loss: 0.2330 - learning_rate: 5.0000e-04
# Epoch 29/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9531 - loss: 0.1410
# Epoch 29: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9535 - loss: 0.1405 - val_accuracy: 0.9313 - val_loss: 0.2823 - learning_rate: 5.0000e-04
# Epoch 30/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9559 - loss: 0.1364
# Epoch 30: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9559 - loss: 0.1358 - val_accuracy: 0.9405 - val_loss: 0.2454 - learning_rate: 5.0000e-04
# Epoch 31/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9569 - loss: 0.1401
# Epoch 31: val_accuracy did not improve from 0.95458
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9556 - loss: 0.1384 - val_accuracy: 0.9429 - val_loss: 0.2194 - learning_rate: 5.0000e-04
# Epoch 32/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9616 - loss: 0.1118
# Epoch 32: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9638 - loss: 0.1081 - val_accuracy: 0.9331 - val_loss: 0.2896 - learning_rate: 2.5000e-04
# Epoch 33/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9669 - loss: 0.0987
# Epoch 33: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9660 - loss: 0.1004 - val_accuracy: 0.9397 - val_loss: 0.2590 - learning_rate: 2.5000e-04
# Epoch 34/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9654 - loss: 0.1080
# Epoch 34: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9660 - loss: 0.1043 - val_accuracy: 0.9466 - val_loss: 0.1971 - learning_rate: 2.5000e-04
# Epoch 35/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9675 - loss: 0.0982
# Epoch 35: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9675 - loss: 0.0977 - val_accuracy: 0.9479 - val_loss: 0.2079 - learning_rate: 2.5000e-04
# Epoch 36/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9681 - loss: 0.0955
# Epoch 36: val_accuracy did not improve from 0.95458
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9673 - loss: 0.0968 - val_accuracy: 0.9444 - val_loss: 0.2158 - learning_rate: 2.5000e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# ✅ First training done

# %%
# =====================================================
# 🔥 LOAD BEST MODEL
# =====================================================
print("\n🔁 Loading BEST model for second training...")
model = tf.keras.models.load_model(MODEL_PATH)

# Lower LR for fine-tuning
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# 🔁 Loading BEST model for second training...

# %%
# =====================================================
# 🔥 SECOND TRAINING
# =====================================================
print("\n🚀 SECOND TRAINING STARTED")

history2 = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[early_stop, checkpoint, reduce_lr],
    verbose=1
)

print("✅ Second training done")
# Out:
# 🚀 SECOND TRAINING STARTED
# Epoch 1/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9597 - loss: 0.1209
# Epoch 1: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 199s 83ms/step - accuracy: 0.9617 - loss: 0.1156 - val_accuracy: 0.9422 - val_loss: 0.2128 - learning_rate: 1.0000e-04
# Epoch 2/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9655 - loss: 0.1054
# Epoch 2: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 198s 83ms/step - accuracy: 0.9644 - loss: 0.1089 - val_accuracy: 0.9336 - val_loss: 0.2488 - learning_rate: 1.0000e-04
# Epoch 3/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9643 - loss: 0.1018
# Epoch 3: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 200s 84ms/step - accuracy: 0.9657 - loss: 0.1017 - val_accuracy: 0.9324 - val_loss: 0.2746 - learning_rate: 1.0000e-04
# Epoch 4/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9674 - loss: 0.0980
# Epoch 4: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 200s 84ms/step - accuracy: 0.9669 - loss: 0.0998 - val_accuracy: 0.9405 - val_loss: 0.2323 - learning_rate: 1.0000e-04
# Epoch 5/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9661 - loss: 0.1001
# Epoch 5: val_accuracy did not improve from 0.95458
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.9667 - loss: 0.1004 - val_accuracy: 0.9425 - val_loss: 0.2269 - learning_rate: 1.0000e-04
# Epoch 6/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9704 - loss: 0.0939
# Epoch 6: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9683 - loss: 0.0964 - val_accuracy: 0.9375 - val_loss: 0.2473 - learning_rate: 5.0000e-05
# Epoch 7/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9713 - loss: 0.0892
# Epoch 7: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.9695 - loss: 0.0914 - val_accuracy: 0.9440 - val_loss: 0.2111 - learning_rate: 5.0000e-05
# Epoch 8/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9694 - loss: 0.0929
# Epoch 8: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.9689 - loss: 0.0937 - val_accuracy: 0.9459 - val_loss: 0.2110 - learning_rate: 5.0000e-05
# Epoch 9/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9699 - loss: 0.0946
# Epoch 9: val_accuracy did not improve from 0.95458
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.9700 - loss: 0.0938 - val_accuracy: 0.9425 - val_loss: 0.2167 - learning_rate: 5.0000e-05
# Epoch 10/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9687 - loss: 0.0955
# Epoch 10: val_accuracy did not improve from 0.95458
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 85ms/step - accuracy: 0.9695 - loss: 0.0934 - val_accuracy: 0.9386 - val_loss: 0.2411 - learning_rate: 5.0000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ✅ Second training done

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# =====================================================
# PLOT FUNCTION
# =====================================================
def plot_training_history(history, model_name="Model"):
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'{model_name} - Training History', fontsize=14, fontweight='bold')

    epochs_ran = range(1, len(history.history['accuracy']) + 1)

    # Accuracy Plot
    axes[0].plot(epochs_ran, history.history['accuracy'], 'b-o', label='Train Accuracy', markersize=4)
    axes[0].plot(epochs_ran, history.history['val_accuracy'], 'r-o', label='Val Accuracy', markersize=4)
    axes[0].set_title('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # Loss Plot
    axes[1].plot(epochs_ran, history.history['loss'], 'b-o', label='Train Loss', markersize=4)
    axes[1].plot(epochs_ran, history.history['val_loss'], 'r-o', label='Val Loss', markersize=4)
    axes[1].set_title('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'{model_name.replace(" ", "_")}_history.png', dpi=100, bbox_inches='tight')
    plt.show()


# =====================================================
# SELECT WHICH HISTORY TO USE 👇
# =====================================================
history = history2   # 👉 jodi 2nd training use korte chao
# history = history1  # 👉 jodi sudhu 1st training use korte chao


# =====================================================
# RUN PLOT + BEST VAL ACC
# =====================================================
plot_training_history(history, "Custom CNN")

if 'val_accuracy' in history.history:
    best_val_acc = max(history.history['val_accuracy'])
    print(f"\n🔥 Best Validation Accuracy: {best_val_acc:.4f} ({best_val_acc*100:.2f}%)")
else:
    print("⚠️ No validation accuracy found!")


# =====================================================
# TEST BEST MODEL
# =====================================================
print("\n🧪 Testing final best model...")

model = tf.keras.models.load_model(MODEL_PATH)

test_loss, test_acc = model.evaluate(test_generator)

print(f"🔥 Final Test Accuracy: {test_acc:.4f}")
# Out:
# 🔥 Best Validation Accuracy: 0.9459 (94.59%)
#
# 🧪 Testing final best model...
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 43s 84ms/step - accuracy: 0.9519 - loss: 0.1657
# 🔥 Final Test Accuracy: 0.9519
