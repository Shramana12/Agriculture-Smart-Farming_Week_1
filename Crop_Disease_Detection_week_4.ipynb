# %% [markdown]
# # 🚀 Week 1: Image Acquisition, EDA, and Preprocessing

# %%
#Imports

import os
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import tensorflow as tf
from collections import Counter

# %%
# INPUT
data_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_color")

# %%
total_images = 0

for class_name in os.listdir(data_dir):
    class_path = data_dir / class_name
    
    if class_path.is_dir():
        num_images = len(os.listdir(class_path))
        total_images += num_images

print("Total Images:", total_images)
# Out:
# Total Images: 54305

# %%
#Exploratory Data Analysis(EDA)
#Class Distribution

class_counts = {}

for class_name in os.listdir(data_dir):
    class_path = data_dir / class_name
    if class_path.is_dir():
        class_counts[class_name] = len(os.listdir(class_path))

# Print counts
for k, v in class_counts.items():
    print(f"{k}: {v}")
# Out:
# Apple___Apple_scab: 630
# Apple___Black_rot: 621
# Apple___Cedar_apple_rust: 275
# Apple___healthy: 1645
# Blueberry___healthy: 1502
# Cherry_(including_sour)___healthy: 854
# Cherry_(including_sour)___Powdery_mildew: 1052
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 513
# Corn_(maize)___Common_rust_: 1192
# Corn_(maize)___healthy: 1162
# Corn_(maize)___Northern_Leaf_Blight: 985
# Grape___Black_rot: 1180
# Grape___Esca_(Black_Measles): 1383
# Grape___healthy: 423
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 1076
# Orange___Haunglongbing_(Citrus_greening): 5507
# Peach___Bacterial_spot: 2297
# Peach___healthy: 360
# Pepper,_bell___Bacterial_spot: 997
# Pepper,_bell___healthy: 1478
# Potato___Early_blight: 1000
# Potato___healthy: 152
# Potato___Late_blight: 1000
# Raspberry___healthy: 371
# Soybean___healthy: 5090
# Squash___Powdery_mildew: 1835
# Strawberry___healthy: 456
# Strawberry___Leaf_scorch: 1109
# Tomato___Bacterial_spot: 2127
# Tomato___Early_blight: 1000
# Tomato___healthy: 1591
# Tomato___Late_blight: 1909
# Tomato___Leaf_Mold: 952
# Tomato___Septoria_leaf_spot: 1771
# Tomato___Spider_mites Two-spotted_spider_mite: 1676
# Tomato___Target_Spot: 1404
# Tomato___Tomato_mosaic_virus: 373
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 5357

# %%
#Plot Class Distribution

plt.figure(figsize=(12,5))
plt.bar(class_counts.keys(), class_counts.values())
plt.xticks(rotation=90)
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %%
#Sample Image Visualization


plt.figure(figsize=(12,8))

classes = list(class_counts.keys())

for i, class_name in enumerate(classes[:9]):  # first 9 classes
    class_path = data_dir / class_name
    img_name = random.choice(os.listdir(class_path))
    img_path = class_path / img_name
    
    img = plt.imread(img_path)
    
    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#Train/Val/Test Split
#Split Function

import shutil
# OUTPUT
output_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")

train_dir = output_dir / "train"
val_dir   = output_dir / "val"
test_dir  = output_dir / "test"


for folder in [train_dir, val_dir, test_dir]:
    folder.mkdir(parents=True, exist_ok=True)

train_ratio = 0.7
val_ratio   = 0.15
test_ratio  = 0.15

# %%
import os, shutil, random
from pathlib import Path

# ✅ INPUT DATASET
data_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_color")

# ✅ OUTPUT
output_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")

train_dir = output_dir / "train"
test_dir  = output_dir / "test"
val_dir = output_dir / "val"

# ✅ clean old split (IMPORTANT)
if output_dir.exists():
    shutil.rmtree(output_dir)

train_dir.mkdir(parents=True, exist_ok=True)
test_dir.mkdir(parents=True, exist_ok=True)
val_dir.mkdir(parents=True, exist_ok=True)
for class_name in os.listdir(data_dir):
    class_path = data_dir / class_name

    if not class_path.is_dir():
        continue

    images = [
        img for img in os.listdir(class_path)
        if img.lower().endswith(('.jpg', '.jpeg', '.png'))
    ]

    random.shuffle(images)

    # ✅ CORRECT INDENTATION
    train_split = int(0.7 * len(images))
    val_split   = int(0.85 * len(images))

    train_images = images[:train_split]
    val_images   = images[train_split:val_split]
    test_images  = images[val_split:]

    for split_name, split_images in zip(
        ['train', 'val', 'test'],
        [train_images, val_images, test_images]
    ):
        split_dir = output_dir / split_name

        (split_dir / class_name).mkdir(parents=True, exist_ok=True)

        for img in split_images:
            src = class_path / img
            dst = split_dir / class_name / img

            shutil.copy2(src, dst)
print("✅ Data Split Done")
# Out:
# ✅ Data Split Done

# %%
data_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_color")

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224,224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224,224),
    batch_size=32
)
# Out:
# Found 54305 files belonging to 38 classes.
# Using 43444 files for training.
# Found 54305 files belonging to 38 classes.
# Using 10861 files for validation.

# %%
#Normalize + Prefetch

normalization_layer = tf.keras.layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y))


AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)

# %%
def print_dataset_details(folder, name):
    print(f"\n📂 {name} Folder:")
    
    total = 0
    
    for class_name in os.listdir(folder):
        class_path = folder / class_name
        
        if class_path.is_dir():
            num_images = len(os.listdir(class_path))
            total += num_images
            print(f"{class_name}: {num_images}")
    
    print(f"👉 Total {name} Images: {total}")
print_dataset_details(train_dir, "Train")
print_dataset_details(val_dir, "Validation")
print_dataset_details(test_dir, "Test")
# Out:
# 📂 Train Folder:
# Apple___Apple_scab: 441
# Apple___Black_rot: 434
# Apple___Cedar_apple_rust: 192
# Apple___healthy: 1151
# Blueberry___healthy: 1051
# Cherry_(including_sour)___healthy: 597
# Cherry_(including_sour)___Powdery_mildew: 736
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 359
# Corn_(maize)___Common_rust_: 834
# Corn_(maize)___healthy: 813
# Corn_(maize)___Northern_Leaf_Blight: 689
# Grape___Black_rot: 826
# Grape___Esca_(Black_Measles): 968
# Grape___healthy: 296
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 753
# Orange___Haunglongbing_(Citrus_greening): 3854
# Peach___Bacterial_spot: 1607
# Peach___healthy: 251
# Pepper,_bell___Bacterial_spot: 697
# Pepper,_bell___healthy: 1034
# Potato___Early_blight: 700
# Potato___healthy: 106
# Potato___Late_blight: 700
# Raspberry___healthy: 259
# Soybean___healthy: 3563
# Squash___Powdery_mildew: 1284
# Strawberry___healthy: 319
# Strawberry___Leaf_scorch: 776
# Tomato___Bacterial_spot: 1488
# Tomato___Early_blight: 700
# Tomato___healthy: 1113
# Tomato___Late_blight: 1336
# Tomato___Leaf_Mold: 666
# Tomato___Septoria_leaf_spot: 1239
# Tomato___Spider_mites Two-spotted_spider_mite: 1173
# Tomato___Target_Spot: 982
# Tomato___Tomato_mosaic_virus: 261
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 3749
# 👉 Total Train Images: 37997
#
# 📂 Validation Folder:
# Apple___Apple_scab: 94
# Apple___Black_rot: 93
# Apple___Cedar_apple_rust: 41
# Apple___healthy: 247
# Blueberry___healthy: 225
# Cherry_(including_sour)___healthy: 128
# Cherry_(including_sour)___Powdery_mildew: 158
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 77
# Corn_(maize)___Common_rust_: 179
# Corn_(maize)___healthy: 174
# Corn_(maize)___Northern_Leaf_Blight: 148
# Grape___Black_rot: 177
# Grape___Esca_(Black_Measles): 207
# Grape___healthy: 63
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 161
# Orange___Haunglongbing_(Citrus_greening): 826
# Peach___Bacterial_spot: 345
# Peach___healthy: 55
# Pepper,_bell___Bacterial_spot: 150
# Pepper,_bell___healthy: 222
# Potato___Early_blight: 150
# Potato___healthy: 23
# Potato___Late_blight: 150
# Raspberry___healthy: 56
# Soybean___healthy: 763
# Squash___Powdery_mildew: 275
# Strawberry___healthy: 68
# Strawberry___Leaf_scorch: 166
# Tomato___Bacterial_spot: 319
# Tomato___Early_blight: 150
# Tomato___healthy: 239
# Tomato___Late_blight: 286
# Tomato___Leaf_Mold: 143
# Tomato___Septoria_leaf_spot: 266
# Tomato___Spider_mites Two-spotted_spider_mite: 251
# Tomato___Target_Spot: 211
# Tomato___Tomato_mosaic_virus: 56
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 804
# 👉 Total Validation Images: 8146
#
# 📂 Test Folder:
# Apple___Apple_scab: 95
# Apple___Black_rot: 94
# Apple___Cedar_apple_rust: 42
# Apple___healthy: 247
# Blueberry___healthy: 226
# Cherry_(including_sour)___healthy: 129
# Cherry_(including_sour)___Powdery_mildew: 158
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 77
# Corn_(maize)___Common_rust_: 179
# Corn_(maize)___healthy: 175
# Corn_(maize)___Northern_Leaf_Blight: 148
# Grape___Black_rot: 177
# Grape___Esca_(Black_Measles): 208
# Grape___healthy: 64
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 162
# Orange___Haunglongbing_(Citrus_greening): 827
# Peach___Bacterial_spot: 345
# Peach___healthy: 54
# Pepper,_bell___Bacterial_spot: 150
# Pepper,_bell___healthy: 222
# Potato___Early_blight: 150
# Potato___healthy: 23
# Potato___Late_blight: 150
# Raspberry___healthy: 56
# Soybean___healthy: 764
# Squash___Powdery_mildew: 276
# Strawberry___healthy: 69
# Strawberry___Leaf_scorch: 167
# Tomato___Bacterial_spot: 320
# Tomato___Early_blight: 150
# Tomato___healthy: 239
# Tomato___Late_blight: 287
# Tomato___Leaf_Mold: 143
# Tomato___Septoria_leaf_spot: 266
# Tomato___Spider_mites Two-spotted_spider_mite: 252
# Tomato___Target_Spot: 211
# Tomato___Tomato_mosaic_virus: 56
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 804
# 👉 Total Test Images: 8162

# %% [markdown]
# # 🚀 WEEK 2: Custom CNN Architecture and Baseline Training

# %%
# =====================================================
# IMPORTS
# =====================================================
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt


print("✅ All libraries imported successfully")
# Out:
# ✅ All libraries imported successfully

# %%
# =====================================================
# PATHS
# =====================================================
base_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")
train_dir = base_dir / "train"
val_dir = base_dir / "val"
test_dir = base_dir / "test"

MODEL_PATH = "best_cnn_model.keras"

# =====================================================
# CONFIG
# =====================================================
IMG_SIZE = (128, 128)
BATCH_SIZE = 16
EPOCHS = 500
NUM_CLASSES = len(os.listdir(train_dir)) #Auto-detect number of class

print(f"Train : {train_dir}")
print(f" Val : {val_dir}")
print(f" Test : {test_dir}")
print(f" Number of Classes : {NUM_CLASSES}")
# Out:
# Train : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\train
#  Val : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\val
#  Test : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\test
#  Number of Classes : 38

# %%
# =====================================================
# DATA GENERATOR
# =====================================================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    fill_mode="nearest"
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

NUM_CLASSES = len(train_generator.class_indices)


NUM_CLASSES= len(train_generator.class_indices)
print(f" Classes loaded: {NUM_CLASSES} classes")
print(f" Train batches : {len(train_generator)}")
print(f" val batches : {len(val_generator)}")
print(f" Test batches : {len(test_generator)}")
# Out:
# Found 37997 images belonging to 38 classes.
# Found 8146 images belonging to 38 classes.
# Found 8162 images belonging to 38 classes.
#  Classes loaded: 38 classes
#  Train batches : 2375
#  val batches : 510
#  Test batches : 511

# %%
# Visualize Augmented Images (sanity check)
import matplotlib.pyplot as plt
import numpy as np

class_names = list(train_generator.class_indices.keys())

sample_batch, sample_labels = next(train_generator)

fig, axes = plt.subplots(3, 4, figsize =(14, 10))
fig.suptitle('Sample Augmented Training Images', fontsize= 16, fontweight= 'bold')

for i, ax in enumerate(axes.flatten()):
    ax.imshow(sample_batch[i])
    label_idx = np.argmax(sample_labels[i])
    ax.set_title(class_names[label_idx][:25],fontsize=8)
    ax.axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('augmented_samples.png',dpi =100, bbox_inches='tight')
plt.show()
print("Augmented Sample images displayed")
# Out:
# Augmented Sample images displayed

# %%
# =====================================================
# MODEL
# =====================================================
def build_custom_cnn(num_classes):
    model = models.Sequential([
        layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(128,128,3)),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model
    

num_classes = 38  
model = build_custom_cnn(num_classes)

model.summary()
# Out:
# C:\Users\Prarthana\.conda\envs\tf_env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 38)                  │           9,766 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 136,038 (531.40 KB)
#  Trainable params: 136,038 (531.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# =====================================================
# CALLBACKS
# =====================================================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    MODEL_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

print(f"✅ Calbacks configured")
print("   • EarlyStopping    (patience=5) ")
print("   • ModelCheckpoint  (save best model)")
print("   • ReduceLROnPlateau (patience=3)")
# Out:
# ✅ Calbacks configured
#    • EarlyStopping    (patience=5)
#    • ModelCheckpoint  (save best model)
#    • ReduceLROnPlateau (patience=3)

# %%
print("Train:", len(train_generator.class_indices))
print("Val:", len(val_generator.class_indices))

print("\nTrain classes:")
print(train_generator.class_indices)

print("\nVal classes:")
print(val_generator.class_indices)
# Out:
# Train: 38
# Val: 38
#
# Train classes:
# {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}
#
# Val classes:
# {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}

# %%
# =====================================================
# 🔥 FIRST TRAINING
# =====================================================
print("\n🚀 FIRST TRAINING STARTED")

model = build_custom_cnn(NUM_CLASSES)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history1 = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[early_stop, checkpoint, reduce_lr],
    verbose=1
)

print("✅ First training done")
# Out:
# 🚀 FIRST TRAINING STARTED
# Epoch 1/500
# C:\Users\Prarthana\.conda\envs\tf_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.2358 - loss: 2.8632
# Epoch 1: val_accuracy improved from None to 0.51743, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 395s 166ms/step - accuracy: 0.3375 - loss: 2.3997 - val_accuracy: 0.5174 - val_loss: 1.5882 - learning_rate: 0.0010
# Epoch 2/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5657 - loss: 1.4675
# Epoch 2: val_accuracy improved from 0.51743 to 0.66401, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 197s 83ms/step - accuracy: 0.5987 - loss: 1.3454 - val_accuracy: 0.6640 - val_loss: 1.1292 - learning_rate: 0.0010
# Epoch 3/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6745 - loss: 1.0625
# Epoch 3: val_accuracy did not improve from 0.66401
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 85ms/step - accuracy: 0.6890 - loss: 1.0193 - val_accuracy: 0.6202 - val_loss: 1.3057 - learning_rate: 0.0010
# Epoch 4/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7206 - loss: 0.8905
# Epoch 4: val_accuracy improved from 0.66401 to 0.81942, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 84ms/step - accuracy: 0.7339 - loss: 0.8531 - val_accuracy: 0.8194 - val_loss: 0.5806 - learning_rate: 0.0010
# Epoch 5/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7677 - loss: 0.7440
# Epoch 5: val_accuracy did not improve from 0.81942
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 198s 83ms/step - accuracy: 0.7724 - loss: 0.7293 - val_accuracy: 0.6818 - val_loss: 1.1816 - learning_rate: 0.0010
# Epoch 6/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7951 - loss: 0.6549
# Epoch 6: val_accuracy improved from 0.81942 to 0.87503, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 199s 84ms/step - accuracy: 0.8001 - loss: 0.6359 - val_accuracy: 0.8750 - val_loss: 0.3868 - learning_rate: 0.0010
# Epoch 7/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8170 - loss: 0.5850
# Epoch 7: val_accuracy did not improve from 0.87503
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 200s 84ms/step - accuracy: 0.8225 - loss: 0.5712 - val_accuracy: 0.8071 - val_loss: 0.6107 - learning_rate: 0.0010
# Epoch 8/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8372 - loss: 0.5152
# Epoch 8: val_accuracy did not improve from 0.87503
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 201s 85ms/step - accuracy: 0.8390 - loss: 0.5139 - val_accuracy: 0.8664 - val_loss: 0.4215 - learning_rate: 0.0010
# Epoch 9/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8476 - loss: 0.4853
# Epoch 9: val_accuracy did not improve from 0.87503
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 206s 87ms/step - accuracy: 0.8516 - loss: 0.4745 - val_accuracy: 0.8707 - val_loss: 0.3919 - learning_rate: 0.0010
# Epoch 10/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8567 - loss: 0.4492
# Epoch 10: val_accuracy did not improve from 0.87503
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 207s 87ms/step - accuracy: 0.8608 - loss: 0.4358 - val_accuracy: 0.8258 - val_loss: 0.5908 - learning_rate: 0.0010
# Epoch 11/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8678 - loss: 0.4118
# Epoch 11: val_accuracy did not improve from 0.87503
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 207s 87ms/step - accuracy: 0.8729 - loss: 0.3981 - val_accuracy: 0.8718 - val_loss: 0.4107 - learning_rate: 0.0010
# Epoch 12/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9021 - loss: 0.3112
# Epoch 12: val_accuracy improved from 0.87503 to 0.91972, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9032 - loss: 0.3063 - val_accuracy: 0.9197 - val_loss: 0.2464 - learning_rate: 5.0000e-04
# Epoch 13/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9063 - loss: 0.2902
# Epoch 13: val_accuracy did not improve from 0.91972
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 85ms/step - accuracy: 0.9059 - loss: 0.2936 - val_accuracy: 0.8673 - val_loss: 0.4841 - learning_rate: 5.0000e-04
# Epoch 14/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9110 - loss: 0.2740
# Epoch 14: val_accuracy did not improve from 0.91972
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9117 - loss: 0.2743 - val_accuracy: 0.9095 - val_loss: 0.3156 - learning_rate: 5.0000e-04
# Epoch 15/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9177 - loss: 0.2490
# Epoch 15: val_accuracy did not improve from 0.91972
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9152 - loss: 0.2616 - val_accuracy: 0.8878 - val_loss: 0.3677 - learning_rate: 5.0000e-04
# Epoch 16/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9186 - loss: 0.2603
# Epoch 16: val_accuracy did not improve from 0.91972
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 207s 87ms/step - accuracy: 0.9189 - loss: 0.2580 - val_accuracy: 0.9160 - val_loss: 0.2713 - learning_rate: 5.0000e-04
# Epoch 17/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9217 - loss: 0.2478
# Epoch 17: val_accuracy did not improve from 0.91972
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 207s 87ms/step - accuracy: 0.9205 - loss: 0.2484 - val_accuracy: 0.8825 - val_loss: 0.4129 - learning_rate: 5.0000e-04
# Epoch 18/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9304 - loss: 0.2154
# Epoch 18: val_accuracy did not improve from 0.91972
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 206s 87ms/step - accuracy: 0.9326 - loss: 0.2087 - val_accuracy: 0.9089 - val_loss: 0.3348 - learning_rate: 2.5000e-04
# Epoch 19/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9361 - loss: 0.1962
# Epoch 19: val_accuracy improved from 0.91972 to 0.92217, saving model to best_cnn_model.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 206s 87ms/step - accuracy: 0.9366 - loss: 0.1970 - val_accuracy: 0.9222 - val_loss: 0.2522 - learning_rate: 2.5000e-04
# Epoch 20/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9351 - loss: 0.1993
# Epoch 20: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 206s 87ms/step - accuracy: 0.9357 - loss: 0.1973 - val_accuracy: 0.9127 - val_loss: 0.3083 - learning_rate: 2.5000e-04
# Epoch 21/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9390 - loss: 0.1919
# Epoch 21: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9369 - loss: 0.1915 - val_accuracy: 0.9162 - val_loss: 0.2830 - learning_rate: 2.5000e-04
# Epoch 22/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9391 - loss: 0.1890
# Epoch 22: val_accuracy did not improve from 0.92217
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9385 - loss: 0.1874 - val_accuracy: 0.9008 - val_loss: 0.3968 - learning_rate: 2.5000e-04
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# ✅ First training done

# %%
# =====================================================
# 🔥 LOAD BEST MODEL
# =====================================================
print("\n🔁 Loading BEST model for second training...")
model = tf.keras.models.load_model(MODEL_PATH)

# Lower LR for fine-tuning
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# 🔁 Loading BEST model for second training...

# %%
# =====================================================
# 🔥 SECOND TRAINING
# =====================================================
print("\n🚀 SECOND TRAINING STARTED")

history2 = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[early_stop, checkpoint, reduce_lr],
    verbose=1
)

print("✅ Second training done")
# Out:
# 🚀 SECOND TRAINING STARTED
# Epoch 1/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9425 - loss: 0.1767
# Epoch 1: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 202s 85ms/step - accuracy: 0.9436 - loss: 0.1748 - val_accuracy: 0.9126 - val_loss: 0.3229 - learning_rate: 1.0000e-04
# Epoch 2/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9420 - loss: 0.1741
# Epoch 2: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 200s 84ms/step - accuracy: 0.9437 - loss: 0.1690 - val_accuracy: 0.9151 - val_loss: 0.3095 - learning_rate: 1.0000e-04
# Epoch 3/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9463 - loss: 0.1637
# Epoch 3: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 85ms/step - accuracy: 0.9460 - loss: 0.1667 - val_accuracy: 0.9109 - val_loss: 0.3157 - learning_rate: 1.0000e-04
# Epoch 4/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9442 - loss: 0.1700
# Epoch 4: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9460 - loss: 0.1659 - val_accuracy: 0.9212 - val_loss: 0.2875 - learning_rate: 1.0000e-04
# Epoch 5/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9474 - loss: 0.1647
# Epoch 5: val_accuracy did not improve from 0.92217
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 203s 86ms/step - accuracy: 0.9465 - loss: 0.1625 - val_accuracy: 0.9170 - val_loss: 0.3011 - learning_rate: 1.0000e-04
# Epoch 6/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9498 - loss: 0.1553
# Epoch 6: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9498 - loss: 0.1562 - val_accuracy: 0.9084 - val_loss: 0.3549 - learning_rate: 5.0000e-05
# Epoch 7/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9498 - loss: 0.1568
# Epoch 7: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9502 - loss: 0.1553 - val_accuracy: 0.8984 - val_loss: 0.4043 - learning_rate: 5.0000e-05
# Epoch 8/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9489 - loss: 0.1536
# Epoch 8: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 207s 87ms/step - accuracy: 0.9497 - loss: 0.1538 - val_accuracy: 0.9197 - val_loss: 0.2981 - learning_rate: 5.0000e-05
# Epoch 9/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9494 - loss: 0.1484
# Epoch 9: val_accuracy did not improve from 0.92217
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 204s 86ms/step - accuracy: 0.9498 - loss: 0.1511 - val_accuracy: 0.9101 - val_loss: 0.3538 - learning_rate: 5.0000e-05
# Epoch 10/500
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9495 - loss: 0.1532
# Epoch 10: val_accuracy did not improve from 0.92217
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 205s 86ms/step - accuracy: 0.9506 - loss: 0.1529 - val_accuracy: 0.9130 - val_loss: 0.3276 - learning_rate: 5.0000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ✅ Second training done

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# =====================================================
# PLOT FUNCTION
# =====================================================
def plot_training_history(history, model_name="Model"):
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'{model_name} - Training History', fontsize=14, fontweight='bold')

    epochs_ran = range(1, len(history.history['accuracy']) + 1)

    # Accuracy Plot
    axes[0].plot(epochs_ran, history.history['accuracy'], 'b-o', label='Train Accuracy', markersize=4)
    axes[0].plot(epochs_ran, history.history['val_accuracy'], 'r-o', label='Val Accuracy', markersize=4)
    axes[0].set_title('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # Loss Plot
    axes[1].plot(epochs_ran, history.history['loss'], 'b-o', label='Train Loss', markersize=4)
    axes[1].plot(epochs_ran, history.history['val_loss'], 'r-o', label='Val Loss', markersize=4)
    axes[1].set_title('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'{model_name.replace(" ", "_")}_history.png', dpi=100, bbox_inches='tight')
    plt.show()


# =====================================================
# SELECT WHICH HISTORY TO USE 👇
# =====================================================
history = history2   # 👉 jodi 2nd training use korte chao
# history = history1  # 👉 jodi sudhu 1st training use korte chao


# =====================================================
# RUN PLOT + BEST VAL ACC
# =====================================================
plot_training_history(history, "Custom CNN")

if 'val_accuracy' in history.history:
    best_val_acc = max(history.history['val_accuracy'])
    print(f"\n🔥 Best Validation Accuracy: {best_val_acc:.4f} ({best_val_acc*100:.2f}%)")
else:
    print("⚠️ No validation accuracy found!")


# =====================================================
# TEST BEST MODEL
# =====================================================
print("\n🧪 Testing final best model...")

model = tf.keras.models.load_model(MODEL_PATH)

test_loss, test_acc = model.evaluate(test_generator)

print(f"🔥 Final Test Accuracy: {test_acc:.4f}")
# Out:
# 🔥 Best Validation Accuracy: 0.9212 (92.12%)
#
# 🧪 Testing final best model...
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - accuracy: 0.9242 - loss: 0.2544
# 🔥 Final Test Accuracy: 0.9242

# %%
# ===============================
# 📊 FINAL ACCURACY REPORT
# ===============================

print("\n📊 FINAL MODEL PERFORMANCE")

# 👉 Training Accuracy (last epoch)
train_acc = history.history['accuracy'][-1]

# 👉 Validation Accuracy (best)
val_acc = max(history.history['val_accuracy'])

# 👉 Test Accuracy (already calculated)
# test_acc = model.evaluate(test_generator) theke peye gecho

print(f"✅ Train Accuracy     : {train_acc:.4f} ({train_acc*100:.2f}%)")
print(f"✅ Validation Accuracy: {val_acc:.4f} ({val_acc*100:.2f}%)")
print(f"✅ Test Accuracy      : {test_acc:.4f} ({test_acc*100:.2f}%)")
# Out:
# 📊 FINAL MODEL PERFORMANCE
# ✅ Train Accuracy     : 0.9506 (95.06%)
# ✅ Validation Accuracy: 0.9212 (92.12%)
# ✅ Test Accuracy      : 0.9242 (92.42%)

# %% [markdown]
# # 🚀 Week 3: Transfer Learning and Hyperparameter Optimization

# %%
# =====================================================
# Imports
# =====================================================

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2, ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix

print("✅ All libraries imported successfully")
# Out:
# ✅ All libraries imported successfully

# %%
# ── Dataset paths ──────────────────────────────
base_dir = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")

train_dir = base_dir / "train"
val_dir   = base_dir / "val"
test_dir  = base_dir / "test"

# Week-2 model path (used for baseline comparison)
WEEK2_MODEL_PATH = "best_cnn_model.keras"

# Week-3 best model will be saved here
WEEK3_MODEL_PATH = "week3_best_transfer_model.keras"

# ── Config ──────────────────────────────────────────────────────────
# MobileNetV2 requires 224×224 input (upgraded from Week 2's 128×128)
IMG_SIZE   = 224
BATCH_SIZE = 32   # increased from 16; 224px images fit fine in GPU memory
EPOCHS     = 200

NUM_CLASSES = len(os.listdir(train_dir))

print(f"Train : {train_dir}")
print(f"Val   : {val_dir}")
print(f"Test  : {test_dir}")
print(f"\n📊 Number of classes detected: {NUM_CLASSES}")
# Out:
# Train : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\train
# Val   : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\val
# Test  : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split\test
#
# 📊 Number of classes detected: 38

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.15,
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    fill_mode="nearest"
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

NUM_CLASSES = train_generator.num_classes

print(f"\n✅ Generators ready")
print(f"   Train batches : {len(train_generator)}")
print(f"   Val batches   : {len(val_generator)}")
print(f"   Test batches  : {len(test_generator)}")
print(f"   Classes       : {NUM_CLASSES}")
# Out:
# Found 37997 images belonging to 38 classes.
# Found 8146 images belonging to 38 classes.
# Found 8162 images belonging to 38 classes.
#
# ✅ Generators ready
#    Train batches : 1188
#    Val batches   : 255
#    Test batches  : 256
#    Classes       : 38

# %%
#Load Week-2 Baseline for Comparison

print("=" * 55)
print("📦 LOADING WEEK-2 BASELINE MODEL FOR COMPARISON")
print("=" * 55)

# Week-2 used 128×128 — build a separate 128×128 test generator just for this
val_test_datagen_128 = ImageDataGenerator(rescale=1./255)
test_generator_128 = val_test_datagen_128.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

try:
    baseline_model = tf.keras.models.load_model(WEEK2_MODEL_PATH)
    baseline_loss, baseline_acc = baseline_model.evaluate(test_generator_128, verbose=0)
    print(f"\n✅ Week-2 Baseline Test Accuracy : {baseline_acc * 100:.2f}%")
    BASELINE_ACC = baseline_acc
except Exception as e:
    print(f"⚠️  Could not load Week-2 model: {e}")
    print("    (Comparison will be skipped at the end)")
    BASELINE_ACC = None
# Out:
# =======================================================
# 📦 LOADING WEEK-2 BASELINE MODEL FOR COMPARISON
# =======================================================
# Found 8162 images belonging to 38 classes.
# C:\Users\Prarthana\.conda\envs\tf_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ✅ Week-2 Baseline Test Accuracy : 92.42%

# %%
#Build Transfer Learning Model

def build_transfer_model(learning_rate=0.0001):
    """
    Transfer Learning model using MobileNetV2 pretrained on ImageNet.
    Base layers are frozen; only the custom classification head is trained
    in Phase 1. Fine-tuning (Phase 2) unlocks the last 30 base layers.
    """
    base_model = MobileNetV2(
        weights="imagenet",
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    base_model.trainable = False   # freeze all pretrained layers

    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.4),
        layers.Dense(NUM_CLASSES, activation="softmax")
    ])

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model, base_model

print("✅ build_transfer_model() defined")
# Out:
# ✅ build_transfer_model() defined

# %%
#Hyperparameter Experiment — Learning Rate Search

print("=" * 55)
print("🔬 HYPERPARAMETER EXPERIMENT: Learning Rate Search")
print("=" * 55)
print("Testing lr = 0.001  vs  lr = 0.0001 (5 quick epochs each)\n")

best_val_acc = 0
best_lr      = None

for lr in [0.001, 0.0001]:
    print(f"\n--- lr = {lr} ---")

    model_exp, _ = build_transfer_model(learning_rate=lr)

    early_stop_exp = EarlyStopping(
        monitor="val_loss", patience=3,
        restore_best_weights=True, verbose=0
    )
    reduce_lr_exp = ReduceLROnPlateau(
        monitor="val_loss", factor=0.3,
        patience=2, min_lr=1e-7, verbose=0
    )

    history_exp = model_exp.fit(
        train_generator,
        validation_data=val_generator,
        epochs=50,
        callbacks=[early_stop_exp, reduce_lr_exp],
        verbose=1
    )

    final_val_acc = max(history_exp.history["val_accuracy"])
    print(f"  → Best val_accuracy : {final_val_acc:.4f}")

    if final_val_acc > best_val_acc:
        best_val_acc = final_val_acc
        best_lr      = lr

print(f"\n✅ Best learning rate selected : {best_lr}  (val_acc = {best_val_acc:.4f})")
# Out:
# =======================================================
# 🔬 HYPERPARAMETER EXPERIMENT: Learning Rate Search
# =======================================================
# Testing lr = 0.001  vs  lr = 0.0001 (5 quick epochs each)
#
#
# --- lr = 0.001 ---
# Epoch 1/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 517s 432ms/step - accuracy: 0.8296 - loss: 0.5742 - val_accuracy: 0.9220 - val_loss: 0.2435 - learning_rate: 0.0010
# Epoch 2/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 505s 425ms/step - accuracy: 0.8915 - loss: 0.3459 - val_accuracy: 0.9238 - val_loss: 0.2267 - learning_rate: 0.0010
# Epoch 3/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 503s 423ms/step - accuracy: 0.9049 - loss: 0.2917 - val_accuracy: 0.9354 - val_loss: 0.1923 - learning_rate: 0.0010
# Epoch 4/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 502s 423ms/step - accuracy: 0.9129 - loss: 0.2699 - val_accuracy: 0.9445 - val_loss: 0.1729 - learning_rate: 0.0010
# Epoch 5/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 501s 422ms/step - accuracy: 0.9161 - loss: 0.2586 - val_accuracy: 0.9441 - val_loss: 0.1715 - learning_rate: 0.0010
# Epoch 6/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 503s 423ms/step - accuracy: 0.9206 - loss: 0.2468 - val_accuracy: 0.9477 - val_loss: 0.1655 - learning_rate: 0.0010
# Epoch 7/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 502s 422ms/step - accuracy: 0.9234 - loss: 0.2361 - val_accuracy: 0.9461 - val_loss: 0.1661 - learning_rate: 0.0010
# Epoch 8/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 504s 424ms/step - accuracy: 0.9260 - loss: 0.2308 - val_accuracy: 0.9429 - val_loss: 0.1845 - learning_rate: 0.0010
# Epoch 9/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 504s 424ms/step - accuracy: 0.9368 - loss: 0.1916 - val_accuracy: 0.9542 - val_loss: 0.1479 - learning_rate: 3.0000e-04
# Epoch 10/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 506s 425ms/step - accuracy: 0.9458 - loss: 0.1625 - val_accuracy: 0.9551 - val_loss: 0.1444 - learning_rate: 3.0000e-04
# Epoch 11/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 507s 426ms/step - accuracy: 0.9475 - loss: 0.1558 - val_accuracy: 0.9567 - val_loss: 0.1364 - learning_rate: 3.0000e-04
# Epoch 12/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 505s 425ms/step - accuracy: 0.9511 - loss: 0.1460 - val_accuracy: 0.9561 - val_loss: 0.1381 - learning_rate: 3.0000e-04
# Epoch 13/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 507s 427ms/step - accuracy: 0.9529 - loss: 0.1405 - val_accuracy: 0.9584 - val_loss: 0.1340 - learning_rate: 3.0000e-04
# Epoch 14/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 428ms/step - accuracy: 0.9536 - loss: 0.1401 - val_accuracy: 0.9599 - val_loss: 0.1316 - learning_rate: 3.0000e-04
# Epoch 15/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 427ms/step - accuracy: 0.9525 - loss: 0.1370 - val_accuracy: 0.9567 - val_loss: 0.1401 - learning_rate: 3.0000e-04
# Epoch 16/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9534 - loss: 0.1361 - val_accuracy: 0.9590 - val_loss: 0.1355 - learning_rate: 3.0000e-04
# Epoch 17/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9580 - loss: 0.1254 - val_accuracy: 0.9596 - val_loss: 0.1335 - learning_rate: 9.0000e-05
#   → Best val_accuracy : 0.9599
#
# --- lr = 0.0001 ---
# Epoch 1/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 513s 430ms/step - accuracy: 0.6668 - loss: 1.2492 - val_accuracy: 0.8772 - val_loss: 0.4179 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 506s 426ms/step - accuracy: 0.8393 - loss: 0.5274 - val_accuracy: 0.9090 - val_loss: 0.2874 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 505s 425ms/step - accuracy: 0.8747 - loss: 0.4022 - val_accuracy: 0.9225 - val_loss: 0.2399 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 506s 426ms/step - accuracy: 0.8949 - loss: 0.3301 - val_accuracy: 0.9341 - val_loss: 0.2042 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9034 - loss: 0.3013 - val_accuracy: 0.9343 - val_loss: 0.1959 - learning_rate: 1.0000e-04
# Epoch 6/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 517s 435ms/step - accuracy: 0.9133 - loss: 0.2657 - val_accuracy: 0.9421 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 7/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 517s 435ms/step - accuracy: 0.9184 - loss: 0.2491 - val_accuracy: 0.9425 - val_loss: 0.1734 - learning_rate: 1.0000e-04
# Epoch 8/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 430ms/step - accuracy: 0.9250 - loss: 0.2289 - val_accuracy: 0.9465 - val_loss: 0.1608 - learning_rate: 1.0000e-04
# Epoch 9/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 427ms/step - accuracy: 0.9278 - loss: 0.2149 - val_accuracy: 0.9451 - val_loss: 0.1627 - learning_rate: 1.0000e-04
# Epoch 10/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9300 - loss: 0.2096 - val_accuracy: 0.9491 - val_loss: 0.1537 - learning_rate: 1.0000e-04
# Epoch 11/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9334 - loss: 0.1973 - val_accuracy: 0.9500 - val_loss: 0.1491 - learning_rate: 1.0000e-04
# Epoch 12/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 429ms/step - accuracy: 0.9375 - loss: 0.1887 - val_accuracy: 0.9483 - val_loss: 0.1523 - learning_rate: 1.0000e-04
# Epoch 13/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9375 - loss: 0.1831 - val_accuracy: 0.9507 - val_loss: 0.1473 - learning_rate: 1.0000e-04
# Epoch 14/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9410 - loss: 0.1758 - val_accuracy: 0.9529 - val_loss: 0.1399 - learning_rate: 1.0000e-04
# Epoch 15/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9422 - loss: 0.1711 - val_accuracy: 0.9518 - val_loss: 0.1441 - learning_rate: 1.0000e-04
# Epoch 16/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9443 - loss: 0.1649 - val_accuracy: 0.9526 - val_loss: 0.1391 - learning_rate: 1.0000e-04
# Epoch 17/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9460 - loss: 0.1600 - val_accuracy: 0.9536 - val_loss: 0.1355 - learning_rate: 1.0000e-04
# Epoch 18/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9464 - loss: 0.1589 - val_accuracy: 0.9547 - val_loss: 0.1340 - learning_rate: 1.0000e-04
# Epoch 19/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9485 - loss: 0.1523 - val_accuracy: 0.9553 - val_loss: 0.1317 - learning_rate: 1.0000e-04
# Epoch 20/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 514s 433ms/step - accuracy: 0.9498 - loss: 0.1530 - val_accuracy: 0.9553 - val_loss: 0.1345 - learning_rate: 1.0000e-04
# Epoch 21/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 429ms/step - accuracy: 0.9509 - loss: 0.1452 - val_accuracy: 0.9554 - val_loss: 0.1318 - learning_rate: 1.0000e-04
# Epoch 22/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 428ms/step - accuracy: 0.9518 - loss: 0.1439 - val_accuracy: 0.9561 - val_loss: 0.1274 - learning_rate: 3.0000e-05
# Epoch 23/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 427ms/step - accuracy: 0.9523 - loss: 0.1393 - val_accuracy: 0.9563 - val_loss: 0.1267 - learning_rate: 3.0000e-05
# Epoch 24/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9552 - loss: 0.1335 - val_accuracy: 0.9558 - val_loss: 0.1279 - learning_rate: 3.0000e-05
# Epoch 25/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 507s 427ms/step - accuracy: 0.9545 - loss: 0.1320 - val_accuracy: 0.9574 - val_loss: 0.1261 - learning_rate: 3.0000e-05
# Epoch 26/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 506s 426ms/step - accuracy: 0.9548 - loss: 0.1332 - val_accuracy: 0.9574 - val_loss: 0.1252 - learning_rate: 3.0000e-05
# Epoch 27/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 506s 426ms/step - accuracy: 0.9555 - loss: 0.1309 - val_accuracy: 0.9575 - val_loss: 0.1242 - learning_rate: 3.0000e-05
# Epoch 28/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 505s 425ms/step - accuracy: 0.9553 - loss: 0.1306 - val_accuracy: 0.9584 - val_loss: 0.1239 - learning_rate: 3.0000e-05
# Epoch 29/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 507s 427ms/step - accuracy: 0.9564 - loss: 0.1286 - val_accuracy: 0.9575 - val_loss: 0.1232 - learning_rate: 3.0000e-05
# Epoch 30/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 464ms/step - accuracy: 0.9583 - loss: 0.1250 - val_accuracy: 0.9565 - val_loss: 0.1260 - learning_rate: 3.0000e-05
# Epoch 31/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 549s 462ms/step - accuracy: 0.9578 - loss: 0.1257 - val_accuracy: 0.9580 - val_loss: 0.1251 - learning_rate: 3.0000e-05
# Epoch 32/50
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 561s 472ms/step - accuracy: 0.9575 - loss: 0.1249 - val_accuracy: 0.9576 - val_loss: 0.1239 - learning_rate: 9.0000e-06
#   → Best val_accuracy : 0.9584
#
# ✅ Best learning rate selected : 0.001  (val_acc = 0.9599)

# %%
#Phase 1 — Full Training (Frozen Base)

print("=" * 55)
print("🚀 PHASE 1 — FULL TRAINING WITH BEST LR (frozen base)")
print("=" * 55)

model, base_model = build_transfer_model(learning_rate=best_lr)
model.summary()

early_stop_p1 = EarlyStopping(
    monitor="val_loss", patience=6,
    restore_best_weights=True, verbose=1
)
checkpoint_p1 = ModelCheckpoint(
    WEEK3_MODEL_PATH, monitor="val_accuracy",
    save_best_only=True, verbose=1
)
reduce_lr_p1 = ReduceLROnPlateau(
    monitor="val_loss", factor=0.3,
    patience=3, min_lr=1e-7, verbose=1
)

history_transfer = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop_p1, checkpoint_p1, reduce_lr_p1],
    verbose=1
)

print("✅ Phase 1 training complete")
# Out:
# =======================================================
# 🚀 PHASE 1 — FULL TRAINING WITH BEST LR (frozen base)
# =======================================================
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_4           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 256)                 │         327,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 38)                  │           9,766 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,600,806 (9.92 MB)
#  Trainable params: 340,262 (1.30 MB)
#  Non-trainable params: 2,260,544 (8.62 MB)
# Epoch 1/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.7533 - loss: 0.9232
# Epoch 1: val_accuracy improved from None to 0.91554, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 536s 449ms/step - accuracy: 0.8313 - loss: 0.5846 - val_accuracy: 0.9155 - val_loss: 0.2523 - learning_rate: 0.0010
# Epoch 2/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8936 - loss: 0.3439
# Epoch 2: val_accuracy improved from 0.91554 to 0.93555, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 515s 434ms/step - accuracy: 0.8939 - loss: 0.3369 - val_accuracy: 0.9356 - val_loss: 0.2060 - learning_rate: 0.0010
# Epoch 3/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.9052 - loss: 0.3013
# Epoch 3: val_accuracy did not improve from 0.93555
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 514s 432ms/step - accuracy: 0.9035 - loss: 0.3054 - val_accuracy: 0.9329 - val_loss: 0.2064 - learning_rate: 0.0010
# Epoch 4/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9140 - loss: 0.2601
# Epoch 4: val_accuracy did not improve from 0.93555
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 428ms/step - accuracy: 0.9118 - loss: 0.2716 - val_accuracy: 0.9329 - val_loss: 0.2028 - learning_rate: 0.0010
# Epoch 5/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9176 - loss: 0.2501
# Epoch 5: val_accuracy improved from 0.93555 to 0.93752, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 503s 423ms/step - accuracy: 0.9170 - loss: 0.2537 - val_accuracy: 0.9375 - val_loss: 0.1904 - learning_rate: 0.0010
# Epoch 6/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9215 - loss: 0.2399
# Epoch 6: val_accuracy improved from 0.93752 to 0.94206, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 503s 423ms/step - accuracy: 0.9203 - loss: 0.2450 - val_accuracy: 0.9421 - val_loss: 0.1752 - learning_rate: 0.0010
# Epoch 7/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9279 - loss: 0.2287
# Epoch 7: val_accuracy did not improve from 0.94206
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 500s 421ms/step - accuracy: 0.9253 - loss: 0.2367 - val_accuracy: 0.9354 - val_loss: 0.1989 - learning_rate: 0.0010
# Epoch 8/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9252 - loss: 0.2256
# Epoch 8: val_accuracy improved from 0.94206 to 0.94476, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 502s 422ms/step - accuracy: 0.9260 - loss: 0.2300 - val_accuracy: 0.9448 - val_loss: 0.1780 - learning_rate: 0.0010
# Epoch 9/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9287 - loss: 0.2244
# Epoch 9: val_accuracy did not improve from 0.94476
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 500s 421ms/step - accuracy: 0.9279 - loss: 0.2258 - val_accuracy: 0.9417 - val_loss: 0.1886 - learning_rate: 0.0010
# Epoch 10/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9373 - loss: 0.1966
# Epoch 10: val_accuracy improved from 0.94476 to 0.95114, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 499s 420ms/step - accuracy: 0.9400 - loss: 0.1856 - val_accuracy: 0.9511 - val_loss: 0.1487 - learning_rate: 3.0000e-04
# Epoch 11/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9423 - loss: 0.1724
# Epoch 11: val_accuracy improved from 0.95114 to 0.95237, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 496s 418ms/step - accuracy: 0.9459 - loss: 0.1586 - val_accuracy: 0.9524 - val_loss: 0.1437 - learning_rate: 3.0000e-04
# Epoch 12/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9490 - loss: 0.1520
# Epoch 12: val_accuracy did not improve from 0.95237
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 498s 419ms/step - accuracy: 0.9484 - loss: 0.1535 - val_accuracy: 0.9520 - val_loss: 0.1481 - learning_rate: 3.0000e-04
# Epoch 13/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9476 - loss: 0.1505
# Epoch 13: val_accuracy improved from 0.95237 to 0.95507, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 500s 421ms/step - accuracy: 0.9495 - loss: 0.1495 - val_accuracy: 0.9551 - val_loss: 0.1366 - learning_rate: 3.0000e-04
# Epoch 14/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9525 - loss: 0.1360
# Epoch 14: val_accuracy did not improve from 0.95507
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 506s 426ms/step - accuracy: 0.9524 - loss: 0.1386 - val_accuracy: 0.9538 - val_loss: 0.1367 - learning_rate: 3.0000e-04
# Epoch 15/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.9527 - loss: 0.1398
# Epoch 15: val_accuracy did not improve from 0.95507
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 507s 427ms/step - accuracy: 0.9531 - loss: 0.1405 - val_accuracy: 0.9537 - val_loss: 0.1365 - learning_rate: 3.0000e-04
# Epoch 16/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.9530 - loss: 0.1362
# Epoch 16: val_accuracy improved from 0.95507 to 0.95716, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9542 - loss: 0.1348 - val_accuracy: 0.9572 - val_loss: 0.1291 - learning_rate: 3.0000e-04
# Epoch 17/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.9556 - loss: 0.1340
# Epoch 17: val_accuracy did not improve from 0.95716
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 508s 428ms/step - accuracy: 0.9548 - loss: 0.1379 - val_accuracy: 0.9557 - val_loss: 0.1341 - learning_rate: 3.0000e-04
# Epoch 18/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9565 - loss: 0.1275
# Epoch 18: val_accuracy did not improve from 0.95716
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 429ms/step - accuracy: 0.9568 - loss: 0.1279 - val_accuracy: 0.9569 - val_loss: 0.1279 - learning_rate: 3.0000e-04
# Epoch 19/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9558 - loss: 0.1268
# Epoch 19: val_accuracy improved from 0.95716 to 0.95863, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 429ms/step - accuracy: 0.9561 - loss: 0.1268 - val_accuracy: 0.9586 - val_loss: 0.1213 - learning_rate: 3.0000e-04
# Epoch 20/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.9573 - loss: 0.1245
# Epoch 20: val_accuracy improved from 0.95863 to 0.95875, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 509s 428ms/step - accuracy: 0.9573 - loss: 0.1256 - val_accuracy: 0.9588 - val_loss: 0.1276 - learning_rate: 3.0000e-04
# Epoch 21/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9588 - loss: 0.1264
# Epoch 21: val_accuracy did not improve from 0.95875
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9590 - loss: 0.1233 - val_accuracy: 0.9580 - val_loss: 0.1268 - learning_rate: 3.0000e-04
# Epoch 22/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9593 - loss: 0.1227
# Epoch 22: val_accuracy improved from 0.95875 to 0.95900, saving model to week3_best_transfer_model.keras
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9588 - loss: 0.1238 - val_accuracy: 0.9590 - val_loss: 0.1317 - learning_rate: 3.0000e-04
# Epoch 23/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9596 - loss: 0.1167
# Epoch 23: val_accuracy improved from 0.95900 to 0.96182, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 510s 430ms/step - accuracy: 0.9604 - loss: 0.1139 - val_accuracy: 0.9618 - val_loss: 0.1209 - learning_rate: 9.0000e-05
# Epoch 24/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9614 - loss: 0.1121
# Epoch 24: val_accuracy improved from 0.96182 to 0.96231, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9620 - loss: 0.1108 - val_accuracy: 0.9623 - val_loss: 0.1187 - learning_rate: 9.0000e-05
# Epoch 25/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9606 - loss: 0.1121
# Epoch 25: val_accuracy did not improve from 0.96231
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 512s 431ms/step - accuracy: 0.9624 - loss: 0.1085 - val_accuracy: 0.9622 - val_loss: 0.1182 - learning_rate: 9.0000e-05
# Epoch 26/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9636 - loss: 0.1031
# Epoch 26: val_accuracy improved from 0.96231 to 0.96280, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 512s 431ms/step - accuracy: 0.9635 - loss: 0.1056 - val_accuracy: 0.9628 - val_loss: 0.1185 - learning_rate: 9.0000e-05
# Epoch 27/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9624 - loss: 0.1085
# Epoch 27: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9633 - loss: 0.1065 - val_accuracy: 0.9624 - val_loss: 0.1169 - learning_rate: 9.0000e-05
# Epoch 28/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9628 - loss: 0.1049
# Epoch 28: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 512s 431ms/step - accuracy: 0.9639 - loss: 0.1023 - val_accuracy: 0.9624 - val_loss: 0.1196 - learning_rate: 9.0000e-05
# Epoch 29/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9649 - loss: 0.1025
# Epoch 29: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9652 - loss: 0.1017 - val_accuracy: 0.9621 - val_loss: 0.1163 - learning_rate: 9.0000e-05
# Epoch 30/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9655 - loss: 0.1008
# Epoch 30: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 512s 431ms/step - accuracy: 0.9653 - loss: 0.0998 - val_accuracy: 0.9621 - val_loss: 0.1206 - learning_rate: 9.0000e-05
# Epoch 31/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9636 - loss: 0.1066
# Epoch 31: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 512s 431ms/step - accuracy: 0.9643 - loss: 0.1049 - val_accuracy: 0.9618 - val_loss: 0.1189 - learning_rate: 9.0000e-05
# Epoch 32/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9642 - loss: 0.1023
# Epoch 32: val_accuracy did not improve from 0.96280
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 511s 430ms/step - accuracy: 0.9658 - loss: 0.1002 - val_accuracy: 0.9621 - val_loss: 0.1194 - learning_rate: 9.0000e-05
# Epoch 33/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9682 - loss: 0.0959
# Epoch 33: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 512s 431ms/step - accuracy: 0.9682 - loss: 0.0961 - val_accuracy: 0.9624 - val_loss: 0.1171 - learning_rate: 2.7000e-05
# Epoch 34/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9661 - loss: 0.0986
# Epoch 34: val_accuracy did not improve from 0.96280
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 513s 432ms/step - accuracy: 0.9668 - loss: 0.0961 - val_accuracy: 0.9623 - val_loss: 0.1166 - learning_rate: 2.7000e-05
# Epoch 35/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9664 - loss: 0.0951
# Epoch 35: val_accuracy did not improve from 0.96280
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 513s 432ms/step - accuracy: 0.9668 - loss: 0.0949 - val_accuracy: 0.9616 - val_loss: 0.1178 - learning_rate: 2.7000e-05
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 29.
# ✅ Phase 1 training complete

# %%
#Phase 2 — Fine-Tuning

print("=" * 55)
print("🔧 PHASE 2 — FINE-TUNING (last 30 MobileNetV2 layers)")
print("=" * 55)

base_model.trainable = True

# Keep earlier feature-extractor layers frozen
for layer in base_model.layers[:-30]:
    layer.trainable = False

# Recompile with a very small lr to avoid destroying pretrained weights
model.compile(
    optimizer=Adam(learning_rate=5e-6),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# Fresh callbacks — never reuse Phase 1 callbacks
early_stop_p2 = EarlyStopping(
    monitor="val_loss", patience=6,
    restore_best_weights=True, verbose=1
)
checkpoint_p2 = ModelCheckpoint(
    WEEK3_MODEL_PATH, monitor="val_accuracy",
    save_best_only=True, verbose=1
)
reduce_lr_p2 = ReduceLROnPlateau(
    monitor="val_loss", factor=0.3,
    patience=3, min_lr=1e-8, verbose=1
)

history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=200,
    callbacks=[early_stop_p2, checkpoint_p2, reduce_lr_p2],
    verbose=1
)

print("✅ Phase 2 fine-tuning complete")
# Out:
# =======================================================
# 🔧 PHASE 2 — FINE-TUNING (last 30 MobileNetV2 layers)
# =======================================================
# Epoch 1/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8548 - loss: 0.5168
# Epoch 1: val_accuracy improved from None to 0.93997, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 578s 483ms/step - accuracy: 0.8745 - loss: 0.4341 - val_accuracy: 0.9400 - val_loss: 0.2216 - learning_rate: 5.0000e-06
# Epoch 2/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9062 - loss: 0.3105
# Epoch 2: val_accuracy improved from 0.93997 to 0.94807, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 570s 480ms/step - accuracy: 0.9092 - loss: 0.2990 - val_accuracy: 0.9481 - val_loss: 0.1742 - learning_rate: 5.0000e-06
# Epoch 3/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9234 - loss: 0.2546
# Epoch 3: val_accuracy improved from 0.94807 to 0.94979, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 571s 481ms/step - accuracy: 0.9250 - loss: 0.2473 - val_accuracy: 0.9498 - val_loss: 0.1653 - learning_rate: 5.0000e-06
# Epoch 4/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9322 - loss: 0.2124
# Epoch 4: val_accuracy improved from 0.94979 to 0.95249, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 570s 480ms/step - accuracy: 0.9347 - loss: 0.2074 - val_accuracy: 0.9525 - val_loss: 0.1516 - learning_rate: 5.0000e-06
# Epoch 5/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9350 - loss: 0.1966
# Epoch 5: val_accuracy improved from 0.95249 to 0.95519, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 569s 479ms/step - accuracy: 0.9374 - loss: 0.1918 - val_accuracy: 0.9552 - val_loss: 0.1439 - learning_rate: 5.0000e-06
# Epoch 6/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9427 - loss: 0.1795
# Epoch 6: val_accuracy improved from 0.95519 to 0.95777, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 570s 480ms/step - accuracy: 0.9443 - loss: 0.1719 - val_accuracy: 0.9578 - val_loss: 0.1346 - learning_rate: 5.0000e-06
# Epoch 7/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9452 - loss: 0.1673
# Epoch 7: val_accuracy improved from 0.95777 to 0.95986, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 571s 481ms/step - accuracy: 0.9470 - loss: 0.1616 - val_accuracy: 0.9599 - val_loss: 0.1289 - learning_rate: 5.0000e-06
# Epoch 8/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9526 - loss: 0.1458
# Epoch 8: val_accuracy improved from 0.95986 to 0.96170, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9523 - loss: 0.1461 - val_accuracy: 0.9617 - val_loss: 0.1241 - learning_rate: 5.0000e-06
# Epoch 9/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9543 - loss: 0.1409
# Epoch 9: val_accuracy improved from 0.96170 to 0.96293, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 570s 480ms/step - accuracy: 0.9539 - loss: 0.1408 - val_accuracy: 0.9629 - val_loss: 0.1198 - learning_rate: 5.0000e-06
# Epoch 10/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9551 - loss: 0.1366
# Epoch 10: val_accuracy improved from 0.96293 to 0.96465, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 482ms/step - accuracy: 0.9569 - loss: 0.1342 - val_accuracy: 0.9646 - val_loss: 0.1197 - learning_rate: 5.0000e-06
# Epoch 11/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9595 - loss: 0.1245
# Epoch 11: val_accuracy improved from 0.96465 to 0.96514, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9591 - loss: 0.1236 - val_accuracy: 0.9651 - val_loss: 0.1142 - learning_rate: 5.0000e-06
# Epoch 12/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9594 - loss: 0.1211
# Epoch 12: val_accuracy did not improve from 0.96514
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9610 - loss: 0.1177 - val_accuracy: 0.9649 - val_loss: 0.1127 - learning_rate: 5.0000e-06
# Epoch 13/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9622 - loss: 0.1148
# Epoch 13: val_accuracy improved from 0.96514 to 0.96710, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9616 - loss: 0.1148 - val_accuracy: 0.9671 - val_loss: 0.1082 - learning_rate: 5.0000e-06
# Epoch 14/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9640 - loss: 0.1045
# Epoch 14: val_accuracy improved from 0.96710 to 0.96870, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9647 - loss: 0.1046 - val_accuracy: 0.9687 - val_loss: 0.1034 - learning_rate: 5.0000e-06
# Epoch 15/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9658 - loss: 0.1032
# Epoch 15: val_accuracy did not improve from 0.96870
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9655 - loss: 0.1027 - val_accuracy: 0.9676 - val_loss: 0.1045 - learning_rate: 5.0000e-06
# Epoch 16/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9657 - loss: 0.0974
# Epoch 16: val_accuracy did not improve from 0.96870
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 573s 482ms/step - accuracy: 0.9660 - loss: 0.0974 - val_accuracy: 0.9669 - val_loss: 0.1047 - learning_rate: 5.0000e-06
# Epoch 17/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9684 - loss: 0.0942
# Epoch 17: val_accuracy did not improve from 0.96870
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 571s 480ms/step - accuracy: 0.9682 - loss: 0.0956 - val_accuracy: 0.9675 - val_loss: 0.1040 - learning_rate: 5.0000e-06
# Epoch 18/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9679 - loss: 0.0916
# Epoch 18: val_accuracy did not improve from 0.96870
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9668 - loss: 0.0941 - val_accuracy: 0.9680 - val_loss: 0.1015 - learning_rate: 1.5000e-06
# Epoch 19/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9697 - loss: 0.0880
# Epoch 19: val_accuracy did not improve from 0.96870
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9703 - loss: 0.0864 - val_accuracy: 0.9682 - val_loss: 0.1003 - learning_rate: 1.5000e-06
# Epoch 20/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9720 - loss: 0.0855
# Epoch 20: val_accuracy did not improve from 0.96870
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 481ms/step - accuracy: 0.9710 - loss: 0.0888 - val_accuracy: 0.9682 - val_loss: 0.0985 - learning_rate: 1.5000e-06
# Epoch 21/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9701 - loss: 0.0887
# Epoch 21: val_accuracy improved from 0.96870 to 0.96943, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 573s 482ms/step - accuracy: 0.9700 - loss: 0.0880 - val_accuracy: 0.9694 - val_loss: 0.0974 - learning_rate: 1.5000e-06
# Epoch 22/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9717 - loss: 0.0890
# Epoch 22: val_accuracy did not improve from 0.96943
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 618s 479ms/step - accuracy: 0.9708 - loss: 0.0899 - val_accuracy: 0.9676 - val_loss: 0.1009 - learning_rate: 1.5000e-06
# Epoch 23/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9700 - loss: 0.0854
# Epoch 23: val_accuracy improved from 0.96943 to 0.96980, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 572s 482ms/step - accuracy: 0.9709 - loss: 0.0853 - val_accuracy: 0.9698 - val_loss: 0.0986 - learning_rate: 1.5000e-06
# Epoch 24/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.9730 - loss: 0.0874
# Epoch 24: val_accuracy improved from 0.96980 to 0.96992, saving model to week3_best_transfer_model.keras
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 574s 483ms/step - accuracy: 0.9730 - loss: 0.0836 - val_accuracy: 0.9699 - val_loss: 0.0977 - learning_rate: 1.5000e-06
# Epoch 25/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9699 - loss: 0.0871
# Epoch 25: val_accuracy improved from 0.96992 to 0.97005, saving model to week3_best_transfer_model.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 575s 484ms/step - accuracy: 0.9711 - loss: 0.0847 - val_accuracy: 0.9700 - val_loss: 0.0980 - learning_rate: 4.5000e-07
# Epoch 26/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.9689 - loss: 0.0851
# Epoch 26: val_accuracy did not improve from 0.97005
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 574s 483ms/step - accuracy: 0.9693 - loss: 0.0879 - val_accuracy: 0.9700 - val_loss: 0.0974 - learning_rate: 4.5000e-07
# Epoch 27/200
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9736 - loss: 0.0812
# Epoch 27: val_accuracy did not improve from 0.97005
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.3499999624855262e-07.
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 574s 483ms/step - accuracy: 0.9727 - loss: 0.0811 - val_accuracy: 0.9700 - val_loss: 0.0975 - learning_rate: 4.5000e-07
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 21.
# ✅ Phase 2 fine-tuning complete

# %%
#Load Best Model & Evaluate

print("=" * 55)
print("📊 EVALUATING BEST WEEK-3 MODEL")
print("=" * 55)

best_model = tf.keras.models.load_model(WEEK3_MODEL_PATH)

val_loss, val_acc   = best_model.evaluate(val_generator,  verbose=0)
test_loss, test_acc = best_model.evaluate(test_generator, verbose=0)

print(f"\nValidation Accuracy : {val_acc  * 100:.2f}%")
print(f"Test Accuracy       : {test_acc * 100:.2f}%")
# Out:
# =======================================================
# 📊 EVALUATING BEST WEEK-3 MODEL
# =======================================================
#
# Validation Accuracy : 97.00%
# Test Accuracy       : 97.34%

# %%
#Classification Report — Precision, Recall & F1

print("=" * 55)
print("📋 CLASSIFICATION REPORT")
print("=" * 55)

test_generator.reset()
y_pred_probs = best_model.predict(test_generator, verbose=1)
y_pred       = np.argmax(y_pred_probs, axis=1)
y_true       = test_generator.classes
class_names  = list(test_generator.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# =======================================================
# 📋 CLASSIFICATION REPORT
# =======================================================
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 67s 258ms/step
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.97      0.94      0.95        95
#                                  Apple___Black_rot       0.98      0.99      0.98        94
#                           Apple___Cedar_apple_rust       0.98      0.98      0.98        42
#                                    Apple___healthy       1.00      0.99      0.99       247
#                                Blueberry___healthy       0.98      1.00      0.99       226
#           Cherry_(including_sour)___Powdery_mildew       1.00      0.99      0.99       158
#                  Cherry_(including_sour)___healthy       0.99      1.00      1.00       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.85      0.91      0.88        77
#                        Corn_(maize)___Common_rust_       1.00      0.99      1.00       179
#                Corn_(maize)___Northern_Leaf_Blight       0.94      0.93      0.94       148
#                             Corn_(maize)___healthy       1.00      1.00      1.00       175
#                                  Grape___Black_rot       0.97      0.99      0.98       177
#                       Grape___Esca_(Black_Measles)       0.99      0.98      0.98       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00       162
#                                    Grape___healthy       1.00      1.00      1.00        64
#           Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00       827
#                             Peach___Bacterial_spot       0.99      1.00      0.99       345
#                                    Peach___healthy       0.98      1.00      0.99        54
#                      Pepper,_bell___Bacterial_spot       0.93      0.99      0.95       150
#                             Pepper,_bell___healthy       0.98      0.99      0.99       222
#                              Potato___Early_blight       0.97      0.99      0.98       150
#                               Potato___Late_blight       0.98      0.93      0.95       150
#                                   Potato___healthy       0.87      0.87      0.87        23
#                                Raspberry___healthy       1.00      0.98      0.99        56
#                                  Soybean___healthy       1.00      1.00      1.00       764
#                            Squash___Powdery_mildew       1.00      1.00      1.00       276
#                           Strawberry___Leaf_scorch       1.00      0.99      0.99       167
#                               Strawberry___healthy       1.00      1.00      1.00        69
#                            Tomato___Bacterial_spot       0.97      0.97      0.97       320
#                              Tomato___Early_blight       0.90      0.79      0.84       150
#                               Tomato___Late_blight       0.94      0.95      0.95       287
#                                 Tomato___Leaf_Mold       0.95      0.96      0.95       143
#                        Tomato___Septoria_leaf_spot       0.94      0.92      0.93       266
#      Tomato___Spider_mites Two-spotted_spider_mite       0.95      0.85      0.90       252
#                               Tomato___Target_Spot       0.80      0.95      0.87       211
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      0.99      1.00       804
#                       Tomato___Tomato_mosaic_virus       0.95      0.95      0.95        56
#                                   Tomato___healthy       0.93      0.98      0.95       239
#
#                                           accuracy                           0.97      8162
#                                          macro avg       0.97      0.97      0.96      8162
#                                       weighted avg       0.97      0.97      0.97      8162

# %%
#Confusion Matrix

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(16, 14))
    sns.heatmap(
        cm,
        annot=True, fmt="d", cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.title("Confusion Matrix – Test Set (Week 3 Transfer Learning)", fontsize=14)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    plt.savefig("week3_confusion_matrix.png", dpi=100, bbox_inches="tight")
    plt.show()
    print("✅ Confusion matrix saved → week3_confusion_matrix.png")

plot_confusion_matrix(y_true, y_pred, class_names)
# Out:
# ✅ Confusion matrix saved → week3_confusion_matrix.png

# %%
#Training Curves — Phase 1 & Phase 2

def plot_history(history, title):
    acc      = history.history["accuracy"]
    val_acc  = history.history["val_accuracy"]
    loss     = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc,     label="Train Accuracy")
    plt.plot(epochs_range, val_acc, label="Val Accuracy")
    plt.title(title + " – Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss,     label="Train Loss")
    plt.plot(epochs_range, val_loss, label="Val Loss")
    plt.title(title + " – Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    fname = title.replace(" ", "_").replace("(", "").replace(")", "") + ".png"
    plt.savefig(fname, dpi=100, bbox_inches="tight")
    plt.show()
    print(f"✅ Training curve saved → {fname}")

plot_history(history_transfer, "Phase 1 Transfer Learning")
plot_history(history_finetune,  "Phase 2 Fine Tuning")
# Out:
# ✅ Training curve saved → Phase_1_Transfer_Learning.png
# ✅ Training curve saved → Phase_2_Fine_Tuning.png

# %%
##### Week-by-Week Progress Summary
print("=" * 55)
print("📈 WEEK-BY-WEEK PROGRESS SUMMARY")
print("=" * 55)

if BASELINE_ACC is not None:
    improvement = (test_acc - BASELINE_ACC) * 100
    print(f"  Week 2  – Custom CNN (128×128)           : {BASELINE_ACC * 100:.2f}%")
    print(f"  Week 3  – MobileNetV2 Transfer (224×224) : {test_acc * 100:.2f}%")
    print(f"  Improvement                              : +{improvement:.2f}%")
else:
    print(f"  Week 3 – MobileNetV2 Transfer Learning Test Accuracy: {test_acc * 100:.2f}%")
    print("  (Week-2 baseline not available for comparison)")

print("\n✅ Week 3 complete!")
print(f"   Best model saved at : {WEEK3_MODEL_PATH}")
# Out:
# =======================================================
# 📈 WEEK-BY-WEEK PROGRESS SUMMARY
# =======================================================
#   Week 2  – Custom CNN (128×128)           : 92.42%
#   Week 3  – MobileNetV2 Transfer (224×224) : 97.34%
#   Improvement                              : +4.93%
#
# ✅ Week 3 complete!
#    Best model saved at : week3_best_transfer_model.keras

# %% [markdown]
# # 🚀 Week 4: Evaluation, Inference, and Deployment

# %%
#import
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# =====================================================
# 📁 PATH SETTINGS
# =====================================================

IMG_SIZE = 224
BATCH_SIZE = 32

SPLIT_DIR = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\PlantVillage_split")

MODEL_PATH = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\week3_best_transfer_model.keras")

SAMPLE_IMAGE_PATH = Path(r"C:\Users\Prarthana\Desktop\Crop_Disease_Detection\sample.jpg")

# %%
# =====================================================
# ✅ TASK 1: LOAD FINAL TRAINED MODEL
# =====================================================

model = tf.keras.models.load_model(MODEL_PATH)

print("✅ Final Model Loaded Successfully")
# Out:
# ✅ Final Model Loaded Successfully

# %%
# =====================================================
# ✅ TASK 2: CREATE TEST GENERATOR
# =====================================================

test_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0
)

test_generator = test_datagen.flow_from_directory(
    SPLIT_DIR / "test",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 8162 images belonging to 38 classes.

# %%
# =====================================================
# ✅ TASK 3: MODEL EVALUATION
# =====================================================

print("\n📊 Evaluating Model...\n")

loss, accuracy = model.evaluate(test_generator)

print(f"Test Accuracy : {accuracy * 100:.2f}%")
print(f"Test Loss     : {loss:.4f}")
# Out:
# 📊 Evaluating Model...
# C:\Users\Prarthana\.conda\envs\tf_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 71s 271ms/step - accuracy: 0.9734 - loss: 0.0904
# Test Accuracy : 97.34%
# Test Loss     : 0.0904

# %%
# =====================================================
# ✅ TASK 4: GENERATE PREDICTIONS
# =====================================================

test_generator.reset()

y_prob = model.predict(test_generator)

y_pred = np.argmax(y_prob, axis=1)

y_true = test_generator.classes

class_names = list(test_generator.class_indices.keys())
# Out:
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 69s 268ms/step

# %%
# =====================================================
# ✅ TASK 5: CLASSIFICATION REPORT
# =====================================================

print("\n📋 Classification Report\n")

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
)

print(report)
# Out:
# 📋 Classification Report
#
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab     0.9674    0.9368    0.9519        95
#                                  Apple___Black_rot     0.9789    0.9894    0.9841        94
#                           Apple___Cedar_apple_rust     0.9762    0.9762    0.9762        42
#                                    Apple___healthy     0.9959    0.9919    0.9939       247
#                                Blueberry___healthy     0.9825    0.9956    0.9890       226
#           Cherry_(including_sour)___Powdery_mildew     1.0000    0.9873    0.9936       158
#                  Cherry_(including_sour)___healthy     0.9923    1.0000    0.9961       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot     0.8537    0.9091    0.8805        77
#                        Corn_(maize)___Common_rust_     1.0000    0.9944    0.9972       179
#                Corn_(maize)___Northern_Leaf_Blight     0.9448    0.9257    0.9352       148
#                             Corn_(maize)___healthy     1.0000    1.0000    1.0000       175
#                                  Grape___Black_rot     0.9722    0.9887    0.9804       177
#                       Grape___Esca_(Black_Measles)     0.9902    0.9760    0.9831       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)     1.0000    1.0000    1.0000       162
#                                    Grape___healthy     1.0000    1.0000    1.0000        64
#           Orange___Haunglongbing_(Citrus_greening)     0.9976    0.9976    0.9976       827
#                             Peach___Bacterial_spot     0.9885    0.9971    0.9928       345
#                                    Peach___healthy     0.9818    1.0000    0.9908        54
#                      Pepper,_bell___Bacterial_spot     0.9250    0.9867    0.9548       150
#                             Pepper,_bell___healthy     0.9821    0.9910    0.9865       222
#                              Potato___Early_blight     0.9675    0.9933    0.9803       150
#                               Potato___Late_blight     0.9789    0.9267    0.9521       150
#                                   Potato___healthy     0.8696    0.8696    0.8696        23
#                                Raspberry___healthy     1.0000    0.9821    0.9910        56
#                                  Soybean___healthy     0.9987    0.9961    0.9974       764
#                            Squash___Powdery_mildew     1.0000    0.9964    0.9982       276
#                           Strawberry___Leaf_scorch     1.0000    0.9880    0.9940       167
#                               Strawberry___healthy     1.0000    1.0000    1.0000        69
#                            Tomato___Bacterial_spot     0.9748    0.9688    0.9718       320
#                              Tomato___Early_blight     0.9008    0.7867    0.8399       150
#                               Tomato___Late_blight     0.9444    0.9477    0.9461       287
#                                 Tomato___Leaf_Mold     0.9514    0.9580    0.9547       143
#                        Tomato___Septoria_leaf_spot     0.9421    0.9173    0.9295       266
#      Tomato___Spider_mites Two-spotted_spider_mite     0.9511    0.8492    0.8973       252
#                               Tomato___Target_Spot     0.7968    0.9479    0.8658       211
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus     0.9987    0.9913    0.9950       804
#                       Tomato___Tomato_mosaic_virus     0.9464    0.9464    0.9464        56
#                                   Tomato___healthy     0.9286    0.9791    0.9532       239
#
#                                           accuracy                         0.9734      8162
#                                          macro avg     0.9652    0.9655    0.9649      8162
#                                       weighted avg     0.9743    0.9734    0.9734      8162

# %%
# =====================================================
# ✅ TASK 6: CONFUSION MATRIX
# Analyze misclassification between diseases
# =====================================================

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(16, 14))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.xticks(rotation=90)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
# =====================================================
# ✅ TASK 7: SAVE FINAL MODEL WEIGHTS
# =====================================================

model.save(MODEL_PATH)

print("\n✅ Final Model Saved Successfully")
# Out:
# ✅ Final Model Saved Successfully

# %%
# =====================================================
# ✅ TASK 8: LOAD CLASS NAMES
# =====================================================

def load_class_names(split_dir):

    train_dir = split_dir / "train"

    class_names = sorted([
        p.name for p in train_dir.iterdir()
        if p.is_dir()
    ])

    return class_names

# %%
# =====================================================
# ✅ TASK 9: INFERENCE FUNCTION
# Takes unseen image path as input
# Outputs:
#   - Predicted Disease
#   - Confidence Score
# =====================================================

def predict_disease(model_path, image_path, split_dir):

    model = tf.keras.models.load_model(model_path)

    class_names = load_class_names(split_dir)

    # Load Image
    img = tf.keras.utils.load_img(
        image_path,
        target_size=(IMG_SIZE, IMG_SIZE)
    )

    # Convert Image to Array
    img_array = tf.keras.utils.img_to_array(img)

    # Normalize Image
    img_array = img_array / 255.0

    # Add Batch Dimension
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = model.predict(img_array, verbose=0)[0]

    predicted_index = np.argmax(predictions)

    predicted_class = class_names[predicted_index]

    confidence = predictions[predicted_index]

    # Output
    print("\n🖼️ Inference Result")
    print("Image Path :", image_path)
    print("Prediction :", predicted_class)
    print(f"Confidence : {confidence * 100:.2f}%")

# %%
# =====================================================
# ✅ TASK 10: TEST ON UNSEEN IMAGE
# =====================================================

if SAMPLE_IMAGE_PATH.exists():

    predict_disease(
        MODEL_PATH,
        SAMPLE_IMAGE_PATH,
        SPLIT_DIR
    )

else:

    print("\n❌ Sample Image Not Found")
# Out:
# 🖼️ Inference Result
# Image Path : C:\Users\Prarthana\Desktop\Crop_Disease_Detection\sample.jpg
# Prediction : Pepper,_bell___Bacterial_spot
# Confidence : 87.25%
